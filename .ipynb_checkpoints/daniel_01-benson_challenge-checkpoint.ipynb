# %% [markdown]
# # Challenge Set 1
#
# Topic:  Explore MTA turnstile data
#
# Date:   01/25/2016
#
# Name:   Daniel Yawitz

# %%
import os, csv, re
import datetime
import dateutil.parser
import numpy as np
import pandas as pd

f = 'turnstile_160109.txt'
#f = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_160109.txt"

# %%
'''DONT RUN THESE SCRIPTS

Only Dan should run these to get his dumb computer to work'''

# import sys
# 
# paths = ['', '/Users/dyawitz/anaconda/bin', '/Users/dyawitz/anaconda/lib/python27.zip', '/Users/dyawitz/anaconda/lib/python2.7/plat-darwin', '/Users/dyawitz/anaconda/lib/python2.7/plat-mac', '/Users/dyawitz/anaconda/lib/python2.7/plat-mac/lib-scriptpackages', '/Users/dyawitz/anaconda/lib/python2.7/lib-tk', '/Users/dyawitz/anaconda/lib/python2.7/lib-old', '/Users/dyawitz/anaconda/lib/python2.7/lib-dynload', '/Users/dyawitz/anaconda/lib/python2.7/site-packages/Sphinx-1.3.1-py2.7.egg', '/Users/dyawitz/anaconda/lib/python2.7/site-packages/setuptools-18.5-py2.7.egg', '/Users/dyawitz/anaconda/lib/python2.7/site-packages', '/Users/dyawitz/anaconda/lib/python2.7/site-packages/aeosa', '/Users/dyawitz/anaconda/lib/python2.7/site-packages/IPython/extensions', '/Users/dyawitz/.ipython']

# for i in paths:
#    sys.path.append(i)
    
#

# %%
#Read in the data:
def read_data(file):
    data = open(file)
    d = []
    csv_data = csv.reader(data)
    for row in csv_data:
        #strip extra spaces from 'EXITS'
        row[10] = row[10].rstrip()
        d.append(row)
    return d
    data.close()

d = read_data(f)
colnames = d[0]
df = pd.DataFrame(d, columns=colnames)
#pop out the headers
df = df.drop([0])

#d.pop(0)
#take a small sample of the data
#d = d[:1000]

'''format of 'd' is a list of lists, for all 11 variables
df is a pandas dataframe'''
# Out:
# "format of 'd' is a list of lists, for all 11 variables"

# %%
df.head(10)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1   A002  R051  02-00-00   59 ST   NQR456      BMT  01/02/2016  03:00:00
# 2   A002  R051  02-00-00   59 ST   NQR456      BMT  01/02/2016  07:00:00
# 3   A002  R051  02-00-00   59 ST   NQR456      BMT  01/02/2016  11:00:00
# 4   A002  R051  02-00-00   59 ST   NQR456      BMT  01/02/2016  15:00:00
# 5   A002  R051  02-00-00   59 ST   NQR456      BMT  01/02/2016  19:00:00
# 6   A002  R051  02-00-00   59 ST   NQR456      BMT  01/02/2016  23:00:00
# 7   A002  R051  02-00-00   59 ST   NQR456      BMT  01/03/2016  03:00:00
# 8   A002  R051  02-00-00   59 ST   NQR456      BMT  01/03/2016  07:00:00
# 9   A002  R051  02-00-00   59 ST   NQR456      BMT  01/03/2016  11:00:00
# 10  A002  R051  02-00-00   59 ST   NQR456      BMT  01/03/2016  15:00:00
#
#        DESC     ENTRIES       EXITS
# 1   REGULAR  0005478180  0001849152
# 2   REGULAR  0005478183  0001849161
# 3   REGULAR  0005478262  0001849240
# 4   REGULAR  0005478519  0001849340
# 5   REGULAR  0005478940  0001849403
# 6   REGULAR  0005479213  0001849445
# 7   REGULAR  0005479279  0001849457
# 8   REGULAR  0005479282  0001849465
# 9   REGULAR  0005479344  0001849513
# 10  REGULAR  0005479558  0001849581

# %% [markdown]
# # Challenge 1
# Make a dictionary so that each turnstile is a key and its 4 hour measurements are values

# %%
def turn_dict(d):
    '''turns the raw data into a dict of the form {turnstile:[values]}
    
    One example value:
    {('A006', 'R079', '00-03-02', '5 AV/59 ST'):
    [['NQR',
   'BMT',
   '01/02/2016',
   '01:00:00',
   'REGULAR',
   '0013206367',
   '0013861091'],
   
  ['NQR',
   'BMT',
   '01/02/2016',
   '05:00:00',
   'REGULAR',
   '0013206371',
   '0013861092']}
    
    '''
    #create empty dict
    mta_dict = {}
    #pop out the headers
#     if d[0] == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
#                        'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
#                        'EXITS']:
#         d.pop(0)
    
    
    for row in d:
        
        #key is the first 4 columns that ID the turnstile
        key = tuple(row[0:4])
        #values are the rest of the data
        value = row[4:11]
        
        #This line does the same thing as the if/else statement below
        mta_dict.setdefault(key, []).append(value) 
        
        #if key in mta_dict:
        #    mta_dict[key].append(value)
        #else:
        #    mta_dict[key] = [value]
            
       
        
    return mta_dict

turnstile_dict = turn_dict(d)

# %% [markdown]
# turnstile_dict is a solution to challenge 1

# %% [markdown]
# # Challenge 2
# Create a new dictionary. The key is the same, but the values are a list of datetime objects and entry values

# %%
def get_datetime_cumulative(d):
    ''' takes in the raw data and exports a dict of the form {turnstile_key: [[datetime_object, counts]]}
     {('A006', 'R079', '00-03-02', '5 AV/59 ST'):
        [[datetime.datetime(2016, 1, 2, 1, 0), '0013206367'],
         [datetime.datetime(2016, 1, 2, 5, 0), '0013206371']]}
    
    '''
    datetime_cumulative = {}
    
    #pop out the headers
#     if d[0] == ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME',
#                        'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES',
#                        'EXITS']:
#         d.pop(0)
    
    for row in d:
        #get datetime object. Row 6 and 7 of 'd' are '2013-12-02' and '15:00:00'
        dt_str = row[6] + ' ' + row[7]
        dt = dateutil.parser.parse(dt_str)
        #row 9 is turnstile entries
        entries = row[9]

        key = tuple(row[0:5])
        values = [dt, entries]
        
        #This line does the same thing as the if/else statement below
        datetime_cumulative.setdefault(key, []).append(values)

        #if key in datetime_cumulative:
        #    datetime_cumulative[key].append(values)
        #else:
        #    datetime_cumulative[key] = [values]
        
        
    return datetime_cumulative

datetime_cumulative = get_datetime_cumulative(d)

# %%
datetime_cumulative.items()[0]
# Out:
# (('N089', 'R139', '00-00-01', 'CANAL ST', 'ACE'),
#  [[datetime.datetime(2016, 1, 2, 3, 0), '0002606533'],
#   [datetime.datetime(2016, 1, 2, 7, 0), '0002606539'],
#   [datetime.datetime(2016, 1, 2, 11, 0), '0002606554'],
#   [datetime.datetime(2016, 1, 2, 15, 0), '0002606614'],
#   [datetime.datetime(2016, 1, 2, 19, 0), '0002606740'],
#   [datetime.datetime(2016, 1, 2, 23, 0), '0002606795'],
#   [datetime.datetime(2016, 1, 3, 3, 0), '0002606817'],
#   [datetime.datetime(2016, 1, 3, 7, 0), '0002606821'],
#   [datetime.datetime(2016, 1, 3, 11, 0), '0002606834'],
#   [datetime.datetime(2016, 1, 3, 15, 0), '0002606874'],
#   [datetime.datetime(2016, 1, 3, 19, 0), '0002606942'],
#   [datetime.datetime(2016, 1, 3, 23, 0), '0002606988'],
#   [datetime.datetime(2016, 1, 4, 3, 0), '0002606996'],
#   [datetime.datetime(2016, 1, 4, 7, 0), '0002606997'],
#   [datetime.datetime(2016, 1, 4, 11, 0), '0002607028'],
#   [datetime.datetime(2016, 1, 4, 15, 0), '0002607079'],
#   [datetime.datetime(2016, 1, 4, 19, 0), '0002607263'],
#   [datetime.datetime(2016, 1, 4, 23, 0), '0002607340'],
#   [datetime.datetime(2016, 1, 5, 3, 0), '0002607342'],
#   [datetime.datetime(2016, 1, 5, 7, 0), '0002607347'],
#   [datetime.datetime(2016, 1, 5, 11, 0), '0002607386'],
#   [datetime.datetime(2016, 1, 5, 15, 0), '0002607443'],
#   [datetime.datetime(2016, 1, 5, 19, 0), '0002607609'],
#   [datetime.datetime(2016, 1, 5, 23, 0), '0002607683'],
#   [datetime.datetime(2016, 1, 6, 3, 0), '0002607692'],
#   [datetime.datetime(2016, 1, 6, 7, 0), '0002607697'],
#   [datetime.datetime(2016, 1, 6, 11, 0), '0002607726'],
#   [datetime.datetime(2016, 1, 6, 15, 0), '0002607779'],
#   [datetime.datetime(2016, 1, 6, 19, 0), '0002607951'],
#   [datetime.datetime(2016, 1, 6, 23, 0), '0002608050'],
#   [datetime.datetime(2016, 1, 7, 3, 0), '0002608054'],
#   [datetime.datetime(2016, 1, 7, 7, 0), '0002608060'],
#   [datetime.datetime(2016, 1, 7, 11, 0), '0002608085'],
#   [datetime.datetime(2016, 1, 7, 15, 0), '0002608162'],
#   [datetime.datetime(2016, 1, 7, 19, 0), '0002608327'],
#   [datetime.datetime(2016, 1, 7, 23, 0), '0002608421'],
#   [datetime.datetime(2016, 1, 8, 3, 0), '0002608435'],
#   [datetime.datetime(2016, 1, 8, 7, 0), '0002608440'],
#   [datetime.datetime(2016, 1, 8, 7, 55, 36), '0002608445'],
#   [datetime.datetime(2016, 1, 8, 8, 1, 50), '0002608447'],
#   [datetime.datetime(2016, 1, 8, 11, 0), '0002608472'],
#   [datetime.datetime(2016, 1, 8, 15, 0), '0002608534'],
#   [datetime.datetime(2016, 1, 8, 19, 0), '0002608699'],
#   [datetime.datetime(2016, 1, 8, 23, 0), '0002608782']])

# %% [markdown]
# datetime_cumulative is a solution to challenge 2

# %% [markdown]
# # Challenge 3
# Use the same keys, but the values should be the total number of passengers for each day per turnstile

# %%
def count_day(my_list):
    #Takes in a list of lists (the values for one turnstile)
    #datetime_cumulative[key]
    #Output is a list of lists that gets the counts for one turnstile's day
    
    ''' [[datetime.datetime(2016, 1, 2, 1, 0), '0013206367'],
         [datetime.datetime(2016, 1, 2, 5, 0), '0013206371']]
         
         -->
         
         [[dateime.datetime(2016, 1,2), 2]]
        
         
         '''
    
    ## Get unique values of dates
    dates = [row[0].date() for row in my_list]
    #make it a set to eliminate duplicates
    dates = set(dates)
    dates = sorted(list(dates))

    result = list()

    for date in dates:
        
        #get tomorrows date. Add one 'day' to today
        tomorrows_date = date + datetime.timedelta(days=1)
        
        #for every entry with today's date, add the count to a list
        todays_entries = [int(x[1]) for x in my_list if x[0].date() == date]
        
        #todays_entries = [int(x[2]) for x in rows if x[0].date() == date]
        #
        if tomorrows_date in dates:
            #if tomorrow's date is in dates, compare the start of tomorrow to the end of today
            tomorrows_entries = [int(x[1]) for x in my_list if x[0].date() == tomorrows_date]
            delta = min(tomorrows_entries)- min(todays_entries)
            
        else:
            #otherwise, use the change in today
            delta = max(todays_entries) - min(todays_entries)
        
        #Before adding it to the dict, make sure it's non-negative
        if delta > 0:
            result.append((date, delta))
        else:
            result.append((date, 0))
    return result

# %%
turnstile_counts = {key:count_day(datetime_cumulative[key]) for key in datetime_cumulative}
''' one {key:value} pair in turnstile_counts looks like: 

{('A002', 'R051', '02-03-06', '59 ST'),
 [(datetime.date(2016, 1, 4), 2278),
  (datetime.date(2016, 1, 5), 2326),
  (datetime.date(2016, 1, 8), 2325),
  (datetime.date(2016, 1, 2), 1159),
  (datetime.date(2016, 1, 3), 915),
  (datetime.date(2016, 1, 6), 2474),
  (datetime.date(2016, 1, 7), 2553)]}

'''
turnstile_counts.items()[0]
# Out:
# (('N089', 'R139', '00-00-01', 'CANAL ST', 'ACE'),
#  [(datetime.date(2016, 1, 2), 284),
#   (datetime.date(2016, 1, 3), 179),
#   (datetime.date(2016, 1, 4), 346),
#   (datetime.date(2016, 1, 5), 350),
#   (datetime.date(2016, 1, 6), 362),
#   (datetime.date(2016, 1, 7), 381),
#   (datetime.date(2016, 1, 8), 347)])

# %% [markdown]
# # Challenge 4
#
# Plot the daily time series for a turnstile.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def plot_turnstile(dictionary, turnstile_key):
    turnstile_data = sorted(dictionary[turnstile_key])

    dates = [x[0] for x in turnstile_data]
    counts = [x[1] for x in turnstile_data]

    plt.figure(figsize=(10,3))
    plt.plot(dates,counts)

# %%
key = ('A002', 'R051', '02-06-00', '59 ST', 'NQR456')
plot_turnstile(turnstile_counts, key)

# %% [markdown]
# # Challenge 5 & 6
# This is just the code and functions. Scroll down to see the solutions.

# %%
def tcounts_to_dailydata(tcounts):
    ''' dict --> list of lists

        restructures turnstile_counts into a list of lists that looks like the original data:

        ['A002', 'R051', '02-03-06', '59 ST', datetime.date(2016, 1, 4), 2278]
    '''
    dailydata = []

    #get a list of the keys, so you can iterate over something 
    turnstiles = tcounts.keys()

    for t in turnstiles:
        for datecounts in tcounts[t]:
            dailydata += [[t[0], t[1], t[2], t[3], t[4], datecounts[0], datecounts[1]]]

    return dailydata

dailydata = tcounts_to_dailydata(turnstile_counts)
for i in range(5): print dailydata[i]
# Out:
# ['N089', 'R139', '00-00-01', 'CANAL ST', 'ACE', datetime.date(2016, 1, 2), 284]
# ['N089', 'R139', '00-00-01', 'CANAL ST', 'ACE', datetime.date(2016, 1, 3), 179]
# ['N089', 'R139', '00-00-01', 'CANAL ST', 'ACE', datetime.date(2016, 1, 4), 346]
# ['N089', 'R139', '00-00-01', 'CANAL ST', 'ACE', datetime.date(2016, 1, 5), 350]
# ['N089', 'R139', '00-00-01', 'CANAL ST', 'ACE', datetime.date(2016, 1, 6), 362]

# %%
def dailydata_to_ac_stationdict(dailydata):
    ''' dict --> dict

    restructures turnstile_counts so that the key is station info (including AC), and the value includes the turnstile ID:

    {('A007', 'R079', '5 AV/59 ST', 'NQ'): [['01-05-01', datetime.date(2016, 1, 4), 0],
      ['01-05-01', datetime.date(2016, 1, 5), 0],
      ['01-05-01', datetime.date(2016, 1, 8), 0],
      ['01-05-01', datetime.date(2016, 1, 2), 0],
      ['01-05-01', datetime.date(2016, 1, 3), 0],
      ['01-05-01', datetime.date(2016, 1, 6), 0],
      ['01-06-01', datetime.date(2016, 1, 4), 1413],
      ['01-06-01', datetime.date(2016, 1, 5), 1204],
      ['01-06-01', datetime.date(2016, 1, 2), 1135],
      ['01-06-01', datetime.date(2016, 1, 3), 847],
      ['01-06-01', datetime.date(2016, 1, 6), 1448],
      ['01-06-01', datetime.date(2016, 1, 7), 172]] }

    '''
    stationdict = {}
    
    for i in range(len(dailydata)-1):
        ca = dailydata[i][0]
        unit = dailydata[i][1]
        scp = dailydata[i][2]
        station = dailydata[i][3]
        line = dailydata[i][4]
        day = dailydata[i][5]
        count = dailydata[i][6]

        key = (ca, unit, station, line)
        value = [scp, day, count]

        stationdict.setdefault(key, []).append(value) 

    # stationdict = {tuple(list(turnstile[0:2])+[turnstile[3]]): 
    #                                  [[turnstile[2],
    #                                     datecounts[i][0],
    #                                     datecounts[i][1]] 
    #                                 for i in range(len(datecounts)-1)]
    #                 for turnstile, datecounts in tcounts.iteritems()}

    return stationdict

ac_stationdict = dailydata_to_ac_stationdict(dailydata)

# %%
def dailydata_to_stationdict(dailydata):
    ''' dict --> dict

    restructures turnstile_counts so that the key is station info, and the value includes the turnstile ID:

    {('5 AV/59 ST', 'NQ'): [['01-05-01', datetime.date(2016, 1, 4), 0],
      ['01-05-01', datetime.date(2016, 1, 5), 0],
      ['01-05-01', datetime.date(2016, 1, 8), 0],
      ['01-05-01', datetime.date(2016, 1, 2), 0],
      ['01-05-01', datetime.date(2016, 1, 3), 0],
      ['01-05-01', datetime.date(2016, 1, 6), 0],
      ['01-06-01', datetime.date(2016, 1, 4), 1413],
      ['01-06-01', datetime.date(2016, 1, 5), 1204],
      ['01-06-01', datetime.date(2016, 1, 2), 1135],
      ['01-06-01', datetime.date(2016, 1, 3), 847],
      ['01-06-01', datetime.date(2016, 1, 6), 1448],
      ['01-06-01', datetime.date(2016, 1, 7), 172]] }

    '''
    stationdict = {}
    
    for i in range(len(dailydata)-1):
        ca = dailydata[i][0]
        unit = dailydata[i][1]
        scp = dailydata[i][2]
        station = dailydata[i][3]
        line = dailydata[i][4]
        day = dailydata[i][5]
        count = dailydata[i][6]

        key = (station, line)
        value = [scp, day, count]

        stationdict.setdefault(key, []).append(value) 

    # stationdict = {tuple(list(turnstile[0:2])+[turnstile[3]]): 
    #                                  [[turnstile[2],
    #                                     datecounts[i][0],
    #                                     datecounts[i][1]] 
    #                                 for i in range(len(datecounts)-1)]
    #                 for turnstile, datecounts in tcounts.iteritems()}

    return stationdict

stationdict = dailydata_to_stationdict(dailydata)

stationdict[('59 ST COLUMBUS', '1ABCD')]
# Out:
# [['00-05-01', datetime.date(2016, 1, 2), 656],
#  ['00-05-01', datetime.date(2016, 1, 3), 399],
#  ['00-05-01', datetime.date(2016, 1, 4), 1038],
#  ['00-05-01', datetime.date(2016, 1, 5), 1186],
#  ['00-05-01', datetime.date(2016, 1, 6), 1284],
#  ['00-05-01', datetime.date(2016, 1, 7), 1248],
#  ['00-05-01', datetime.date(2016, 1, 8), 1354],
#  ['00-05-03', datetime.date(2016, 1, 2), 0],
#  ['00-05-03', datetime.date(2016, 1, 3), 0],
#  ['00-05-03', datetime.date(2016, 1, 4), 0],
#  ['00-05-03', datetime.date(2016, 1, 5), 0],
#  ['00-05-03', datetime.date(2016, 1, 6), 0],
#  ['00-05-03', datetime.date(2016, 1, 7), 0],
#  ['00-05-03', datetime.date(2016, 1, 8), 0],
#  ['00-05-02', datetime.date(2016, 1, 2), 175],
#  ['00-05-02', datetime.date(2016, 1, 3), 111],
#  ['00-05-02', datetime.date(2016, 1, 4), 415],
#  ['00-05-02', datetime.date(2016, 1, 5), 413],
#  ['00-05-02', datetime.date(2016, 1, 6), 405],
#  ['00-05-02', datetime.date(2016, 1, 7), 387],
#  ['00-05-02', datetime.date(2016, 1, 8), 485],
#  ['00-02-00', datetime.date(2016, 1, 2), 339],
#  ['00-02-00', datetime.date(2016, 1, 3), 312],
#  ['00-02-00', datetime.date(2016, 1, 4), 511],
#  ['00-02-00', datetime.date(2016, 1, 5), 550],
#  ['00-02-00', datetime.date(2016, 1, 6), 609],
#  ['00-02-00', datetime.date(2016, 1, 7), 630],
#  ['00-02-00', datetime.date(2016, 1, 8), 586],
#  ['00-00-01', datetime.date(2016, 1, 2), 880],
#  ['00-00-01', datetime.date(2016, 1, 3), 671],
#  ['00-00-01', datetime.date(2016, 1, 4), 1328],
#  ['00-00-01', datetime.date(2016, 1, 5), 1420],
#  ['00-00-01', datetime.date(2016, 1, 6), 1375],
#  ['00-00-01', datetime.date(2016, 1, 7), 1439],
#  ['00-00-01', datetime.date(2016, 1, 8), 1310],
#  ['00-00-02', datetime.date(2016, 1, 2), 754],
#  ['00-00-02', datetime.date(2016, 1, 3), 610],
#  ['00-00-02', datetime.date(2016, 1, 4), 1179],
#  ['00-00-02', datetime.date(2016, 1, 5), 1214],
#  ['00-00-02', datetime.date(2016, 1, 6), 1165],
#  ['00-00-02', datetime.date(2016, 1, 7), 1313],
#  ['00-00-02', datetime.date(2016, 1, 8), 1175],
#  ['00-05-04', datetime.date(2016, 1, 2), 0],
#  ['00-05-04', datetime.date(2016, 1, 3), 0],
#  ['00-05-04', datetime.date(2016, 1, 4), 0],
#  ['00-05-04', datetime.date(2016, 1, 5), 0],
#  ['00-05-04', datetime.date(2016, 1, 6), 0],
#  ['00-05-04', datetime.date(2016, 1, 7), 0],
#  ['00-05-04', datetime.date(2016, 1, 8), 0],
#  ['00-05-00', datetime.date(2016, 1, 2), 902],
#  ['00-05-00', datetime.date(2016, 1, 3), 644],
#  ['00-05-00', datetime.date(2016, 1, 4), 1420],
#  ['00-05-00', datetime.date(2016, 1, 5), 1599],
#  ['00-05-00', datetime.date(2016, 1, 6), 1647],
#  ['00-05-00', datetime.date(2016, 1, 7), 1654],
#  ['00-05-00', datetime.date(2016, 1, 8), 1359],
#  ['00-06-01', datetime.date(2016, 1, 2), 1285],
#  ['00-06-01', datetime.date(2016, 1, 3), 935],
#  ['00-06-01', datetime.date(2016, 1, 4), 1519],
#  ['00-06-01', datetime.date(2016, 1, 5), 1715],
#  ['00-06-01', datetime.date(2016, 1, 6), 1549],
#  ['00-06-01', datetime.date(2016, 1, 7), 1518],
#  ['00-06-01', datetime.date(2016, 1, 8), 1383],
#  ['00-06-02', datetime.date(2016, 1, 2), 1269],
#  ['00-06-02', datetime.date(2016, 1, 3), 1053],
#  ['00-06-02', datetime.date(2016, 1, 4), 1626],
#  ['00-06-02', datetime.date(2016, 1, 5), 1899],
#  ['00-06-02', datetime.date(2016, 1, 6), 2098],
#  ['00-06-02', datetime.date(2016, 1, 7), 2000],
#  ['00-06-02', datetime.date(2016, 1, 8), 1837],
#  ['00-06-00', datetime.date(2016, 1, 2), 0],
#  ['00-06-00', datetime.date(2016, 1, 3), 0],
#  ['00-06-00', datetime.date(2016, 1, 4), 0],
#  ['00-06-00', datetime.date(2016, 1, 5), 758],
#  ['00-06-00', datetime.date(2016, 1, 6), 892],
#  ['00-06-00', datetime.date(2016, 1, 7), 822],
#  ['00-06-00', datetime.date(2016, 1, 8), 759],
#  ['00-00-00', datetime.date(2016, 1, 2), 373],
#  ['00-00-00', datetime.date(2016, 1, 3), 400],
#  ['00-00-00', datetime.date(2016, 1, 4), 557],
#  ['00-00-00', datetime.date(2016, 1, 5), 506],
#  ['00-00-00', datetime.date(2016, 1, 6), 537],
#  ['00-00-00', datetime.date(2016, 1, 7), 546],
#  ['00-00-00', datetime.date(2016, 1, 8), 546],
#  ['00-02-01', datetime.date(2016, 1, 2), 471],
#  ['00-02-01', datetime.date(2016, 1, 3), 347],
#  ['00-02-01', datetime.date(2016, 1, 4), 740],
#  ['00-02-01', datetime.date(2016, 1, 5), 823],
#  ['00-02-01', datetime.date(2016, 1, 6), 824],
#  ['00-02-01', datetime.date(2016, 1, 7), 829],
#  ['00-02-01', datetime.date(2016, 1, 8), 812]]

# %%
def get_stationcounts(stationdict):
    ''' Takes the stationdict and adds up the daily totals for all those turnstiles.
    
    {('A047', 'R087', 'CITY HALL'):
    [[datetime.date(2016, 1, 4), 1020],
    [datetime.date(2016, 1, 5), 815],
    [datetime.date(2016, 1, 6), 1030]]}
    
    '''
    stations = stationdict.keys()
    
    stationcounts = {}
    
    for key in stations:
        rows = stationdict[key]
        
        dates = [row[1] for row in rows]
        dates = set(dates)
        dates = sorted(list(dates))
        
        day_sums = list()

        for date in dates:
            todays_entries = [int(x[2]) for x in rows if x[1] == date]
            daily_sum = sum(todays_entries)
            day_sums.append([date, daily_sum])
        stationcounts[key] = day_sums
        #stationcounts.setdefault(key, []).append(day_sums)
        
#         if key in stationcounts.keys():
#             stationcounts[key].append(day_sums)
#         else:
#             stationcounts[key] = [day_sums]
    
    return stationcounts

stationcounts = get_stationcounts(stationdict)
stationcounts.items()[0]
# Out:
# (('OCEAN PKWY', 'Q'),
#  [[datetime.date(2016, 1, 2), 1661],
#   [datetime.date(2016, 1, 3), 1488],
#   [datetime.date(2016, 1, 4), 3124],
#   [datetime.date(2016, 1, 5), 3131],
#   [datetime.date(2016, 1, 6), 3336],
#   [datetime.date(2016, 1, 7), 3346],
#   [datetime.date(2016, 1, 8), 3172]])

# %%
stations = stationcounts.keys()

# %% [markdown]
# # Challenge 5
# -combine the numbers together -- for each ControlArea/UNIT/STATION combo, for each day, add the counts from each turnstile belonging to that combo
# -make this a new dict

# %%
challenge5 = get_stationcounts(ac_stationdict)

print challenge5.items()[0]
# Out:
# (('A002', 'R051', '59 ST', 'NQR456'), [[datetime.date(2016, 1, 2), 10830], [datetime.date(2016, 1, 3), 7982], [datetime.date(2016, 1, 4), 17156], [datetime.date(2016, 1, 5), 16463], [datetime.date(2016, 1, 6), 17865], [datetime.date(2016, 1, 7), 17924], [datetime.date(2016, 1, 8), 17447]])

# %% [markdown]
# # Challenge 6
# Create a dictionary for stations and their daily entries

# %%
stationcounts = get_stationcounts(stationdict)
print stationcounts.items()[1:2]
# Out:
# [(('BAY RIDGE AV', 'R'), [[datetime.date(2016, 1, 2), 7611], [datetime.date(2016, 1, 3), 6099], [datetime.date(2016, 1, 4), 14369], [datetime.date(2016, 1, 5), 14245], [datetime.date(2016, 1, 6), 14813], [datetime.date(2016, 1, 7), 14826], [datetime.date(2016, 1, 8), 14533]])]

# %%
def stationcounts_to_lists(stationcounts):
    '''transforms station counts for other manipulation and export to csv'''
    result = []
    
    stations = stationcounts.keys()
    
    for s in stations:
        for row in stationcounts[s]:
            result += [[s[0], s[1], row[0], row[1]]]
    
    return result

dailystationdata = stationcounts_to_lists(stationcounts)

dailystationdata
# Out:
# [['OCEAN PKWY', 'Q', datetime.date(2016, 1, 2), 1661],
#  ['OCEAN PKWY', 'Q', datetime.date(2016, 1, 3), 1488],
#  ['OCEAN PKWY', 'Q', datetime.date(2016, 1, 4), 3124],
#  ['OCEAN PKWY', 'Q', datetime.date(2016, 1, 5), 3131],
#  ['OCEAN PKWY', 'Q', datetime.date(2016, 1, 6), 3336],
#  ['OCEAN PKWY', 'Q', datetime.date(2016, 1, 7), 3346],
#  ['OCEAN PKWY', 'Q', datetime.date(2016, 1, 8), 3172],
#  ['BAY RIDGE AV', 'R', datetime.date(2016, 1, 2), 7611],
#  ['BAY RIDGE AV', 'R', datetime.date(2016, 1, 3), 6099],
#  ['BAY RIDGE AV', 'R', datetime.date(2016, 1, 4), 14369],
#  ['BAY RIDGE AV', 'R', datetime.date(2016, 1, 5), 14245],
#  ['BAY RIDGE AV', 'R', datetime.date(2016, 1, 6), 14813],
#  ['BAY RIDGE AV', 'R', datetime.date(2016, 1, 7), 14826],
#  ['BAY RIDGE AV', 'R', datetime.date(2016, 1, 8), 14533],
#  ['COURT SQ-23 ST', 'EMG', datetime.date(2016, 1, 2), 3042],
#  ['COURT SQ-23 ST', 'EMG', datetime.date(2016, 1, 3), 2426],
#  ['COURT SQ-23 ST', 'EMG', datetime.date(2016, 1, 4), 10381],
#  ['COURT SQ-23 ST', 'EMG', datetime.date(2016, 1, 5), 8237],
#  ['COURT SQ-23 ST', 'EMG', datetime.date(2016, 1, 6), 8348],
#  ['COURT SQ-23 ST', 'EMG', datetime.date(2016, 1, 7), 8550],
#  ['COURT SQ-23 ST', 'EMG', datetime.date(2016, 1, 8), 8044],
#  ['53 ST', 'R', datetime.date(2016, 1, 2), 4373],
#  ['53 ST', 'R', datetime.date(2016, 1, 3), 3711],
#  ['53 ST', 'R', datetime.date(2016, 1, 4), 7342],
#  ['53 ST', 'R', datetime.date(2016, 1, 5), 7135],
#  ['53 ST', 'R', datetime.date(2016, 1, 6), 7367],
#  ['53 ST', 'R', datetime.date(2016, 1, 7), 7178],
#  ['53 ST', 'R', datetime.date(2016, 1, 8), 7339],
#  ['116 ST', 'BC', datetime.date(2016, 1, 2), 3970],
#  ['116 ST', 'BC', datetime.date(2016, 1, 3), 3684],
#  ['116 ST', 'BC', datetime.date(2016, 1, 4), 7000],
#  ['116 ST', 'BC', datetime.date(2016, 1, 5), 7146],
#  ['116 ST', 'BC', datetime.date(2016, 1, 6), 7362],
#  ['116 ST', 'BC', datetime.date(2016, 1, 7), 7242],
#  ['116 ST', 'BC', datetime.date(2016, 1, 8), 6951],
#  ['CATHEDRAL PKWY', '1', datetime.date(2016, 1, 2), 8217],
#  ['CATHEDRAL PKWY', '1', datetime.date(2016, 1, 3), 7047],
#  ['CATHEDRAL PKWY', '1', datetime.date(2016, 1, 4), 12117],
#  ['CATHEDRAL PKWY', '1', datetime.date(2016, 1, 5), 12416],
#  ['CATHEDRAL PKWY', '1', datetime.date(2016, 1, 6), 13090],
#  ['CATHEDRAL PKWY', '1', datetime.date(2016, 1, 7), 13025],
#  ['CATHEDRAL PKWY', '1', datetime.date(2016, 1, 8), 11695],
#  ['BAY PKWY', 'D', datetime.date(2016, 1, 2), 6878],
#  ['BAY PKWY', 'D', datetime.date(2016, 1, 3), 6148],
#  ['BAY PKWY', 'D', datetime.date(2016, 1, 4), 7561],
#  ['BAY PKWY', 'D', datetime.date(2016, 1, 5), 7212],
#  ['BAY PKWY', 'D', datetime.date(2016, 1, 6), 7642],
#  ['BAY PKWY', 'D', datetime.date(2016, 1, 7), 7662],
#  ['BAY PKWY', 'D', datetime.date(2016, 1, 8), 7262],
#  ['7 AV', 'BQ', datetime.date(2016, 1, 2), 4995],
#  ['7 AV', 'BQ', datetime.date(2016, 1, 3), 4090],
#  ['7 AV', 'BQ', datetime.date(2016, 1, 4), 9240],
#  ['7 AV', 'BQ', datetime.date(2016, 1, 5), 9605],
#  ['7 AV', 'BQ', datetime.date(2016, 1, 6), 9874],
#  ['7 AV', 'BQ', datetime.date(2016, 1, 7), 10136],
#  ['7 AV', 'BQ', datetime.date(2016, 1, 8), 9041],
#  ['CHAMBERS ST', 'ACE23', datetime.date(2016, 1, 2), 14964],
#  ['CHAMBERS ST', 'ACE23', datetime.date(2016, 1, 3), 9733],
#  ['CHAMBERS ST', 'ACE23', datetime.date(2016, 1, 4), 36603],
#  ['CHAMBERS ST', 'ACE23', datetime.date(2016, 1, 5), 37078],
#  ['CHAMBERS ST', 'ACE23', datetime.date(2016, 1, 6), 38376],
#  ['CHAMBERS ST', 'ACE23', datetime.date(2016, 1, 7), 38392],
#  ['CHAMBERS ST', 'ACE23', datetime.date(2016, 1, 8), 35351],
#  ['GREENPOINT AV', 'G', datetime.date(2016, 1, 2), 5173],
#  ['GREENPOINT AV', 'G', datetime.date(2016, 1, 3), 4001],
#  ['GREENPOINT AV', 'G', datetime.date(2016, 1, 4), 9115],
#  ['GREENPOINT AV', 'G', datetime.date(2016, 1, 5), 9282],
#  ['GREENPOINT AV', 'G', datetime.date(2016, 1, 6), 9515],
#  ['GREENPOINT AV', 'G', datetime.date(2016, 1, 7), 9496],
#  ['GREENPOINT AV', 'G', datetime.date(2016, 1, 8), 9495],
#  ['VERNON-JACKSON', '7', datetime.date(2016, 1, 2), 8075],
#  ['VERNON-JACKSON', '7', datetime.date(2016, 1, 3), 6216],
#  ['VERNON-JACKSON', '7', datetime.date(2016, 1, 4), 10441],
#  ['VERNON-JACKSON', '7', datetime.date(2016, 1, 5), 14928],
#  ['VERNON-JACKSON', '7', datetime.date(2016, 1, 6), 15668],
#  ['VERNON-JACKSON', '7', datetime.date(2016, 1, 7), 16034],
#  ['VERNON-JACKSON', '7', datetime.date(2016, 1, 8), 15598],
#  ['BUHRE AV', '6', datetime.date(2016, 1, 2), 1452],
#  ['BUHRE AV', '6', datetime.date(2016, 1, 3), 1096],
#  ['BUHRE AV', '6', datetime.date(2016, 1, 4), 3386],
#  ['BUHRE AV', '6', datetime.date(2016, 1, 5), 3333],
#  ['BUHRE AV', '6', datetime.date(2016, 1, 6), 3533],
#  ['BUHRE AV', '6', datetime.date(2016, 1, 7), 3629],
#  ['BUHRE AV', '6', datetime.date(2016, 1, 8), 3635],
#  ['55 ST', 'D', datetime.date(2016, 1, 2), 697],
#  ['55 ST', 'D', datetime.date(2016, 1, 3), 1037],
#  ['55 ST', 'D', datetime.date(2016, 1, 4), 2141],
#  ['55 ST', 'D', datetime.date(2016, 1, 5), 2075],
#  ['55 ST', 'D', datetime.date(2016, 1, 6), 2077],
#  ['55 ST', 'D', datetime.date(2016, 1, 7), 2168],
#  ['55 ST', 'D', datetime.date(2016, 1, 8), 1939],
#  ['SPRING ST', '6', datetime.date(2016, 1, 2), 9478],
#  ['SPRING ST', '6', datetime.date(2016, 1, 3), 6403],
#  ['SPRING ST', '6', datetime.date(2016, 1, 4), 10203],
#  ['SPRING ST', '6', datetime.date(2016, 1, 5), 10181],
#  ['SPRING ST', '6', datetime.date(2016, 1, 6), 10617],
#  ['SPRING ST', '6', datetime.date(2016, 1, 7), 10690],
#  ['SPRING ST', '6', datetime.date(2016, 1, 8), 10690],
#  ['111 ST', 'J', datetime.date(2016, 1, 2), 1360],
#  ['111 ST', 'J', datetime.date(2016, 1, 3), 1241],
#  ['111 ST', 'J', datetime.date(2016, 1, 4), 2728],
#  ['111 ST', 'J', datetime.date(2016, 1, 5), 2011],
#  ['111 ST', 'J', datetime.date(2016, 1, 6), 2703],
#  ['111 ST', 'J', datetime.date(2016, 1, 7), 2688],
#  ['111 ST', 'J', datetime.date(2016, 1, 8), 2752],
#  ['42 ST-PORT AUTH', 'ACENQRS1237', datetime.date(2016, 1, 2), 54049],
#  ['42 ST-PORT AUTH', 'ACENQRS1237', datetime.date(2016, 1, 3), 43212],
#  ['42 ST-PORT AUTH', 'ACENQRS1237', datetime.date(2016, 1, 4), 77550],
#  ['42 ST-PORT AUTH', 'ACENQRS1237', datetime.date(2016, 1, 5), 78543],
#  ['42 ST-PORT AUTH', 'ACENQRS1237', datetime.date(2016, 1, 6), 76498],
#  ['42 ST-PORT AUTH', 'ACENQRS1237', datetime.date(2016, 1, 7), 76699],
#  ['42 ST-PORT AUTH', 'ACENQRS1237', datetime.date(2016, 1, 8), 82390],
#  ['AVENUE U', 'BQ', datetime.date(2016, 1, 2), 3677],
#  ['AVENUE U', 'BQ', datetime.date(2016, 1, 3), 3123],
#  ['AVENUE U', 'BQ', datetime.date(2016, 1, 4), 6889],
#  ['AVENUE U', 'BQ', datetime.date(2016, 1, 5), 6761],
#  ['AVENUE U', 'BQ', datetime.date(2016, 1, 6), 7069],
#  ['AVENUE U', 'BQ', datetime.date(2016, 1, 7), 6923],
#  ['AVENUE U', 'BQ', datetime.date(2016, 1, 8), 6681],
#  ['161/YANKEE STAD', '4BD', datetime.date(2016, 1, 2), 4808],
#  ['161/YANKEE STAD', '4BD', datetime.date(2016, 1, 3), 3899],
#  ['161/YANKEE STAD', '4BD', datetime.date(2016, 1, 4), 8334],
#  ['161/YANKEE STAD', '4BD', datetime.date(2016, 1, 5), 8459],
#  ['161/YANKEE STAD', '4BD', datetime.date(2016, 1, 6), 9014],
#  ['161/YANKEE STAD', '4BD', datetime.date(2016, 1, 7), 9099],
#  ['161/YANKEE STAD', '4BD', datetime.date(2016, 1, 8), 8991],
#  ['BEVERLY RD', '25', datetime.date(2016, 1, 2), 2487],
#  ['BEVERLY RD', '25', datetime.date(2016, 1, 3), 1955],
#  ['BEVERLY RD', '25', datetime.date(2016, 1, 4), 4396],
#  ['BEVERLY RD', '25', datetime.date(2016, 1, 5), 4336],
#  ['BEVERLY RD', '25', datetime.date(2016, 1, 6), 4582],
#  ['BEVERLY RD', '25', datetime.date(2016, 1, 7), 4537],
#  ['BEVERLY RD', '25', datetime.date(2016, 1, 8), 4546],
#  ['86 ST', 'R', datetime.date(2016, 1, 2), 6891],
#  ['86 ST', 'R', datetime.date(2016, 1, 3), 5422],
#  ['86 ST', 'R', datetime.date(2016, 1, 4), 12001],
#  ['86 ST', 'R', datetime.date(2016, 1, 5), 11585],
#  ['86 ST', 'R', datetime.date(2016, 1, 6), 12128],
#  ['86 ST', 'R', datetime.date(2016, 1, 7), 12143],
#  ['86 ST', 'R', datetime.date(2016, 1, 8), 12385],
#  ['36 AV', 'NQ', datetime.date(2016, 1, 2), 4535],
#  ['36 AV', 'NQ', datetime.date(2016, 1, 3), 3430],
#  ['36 AV', 'NQ', datetime.date(2016, 1, 4), 6963],
#  ['36 AV', 'NQ', datetime.date(2016, 1, 5), 6573],
#  ['36 AV', 'NQ', datetime.date(2016, 1, 6), 6966],
#  ['36 AV', 'NQ', datetime.date(2016, 1, 7), 6979],
#  ['36 AV', 'NQ', datetime.date(2016, 1, 8), 7062],
#  ['34 ST-HERALD SQ', 'BDFMNQR', datetime.date(2016, 1, 2), 74992],
#  ['34 ST-HERALD SQ', 'BDFMNQR', datetime.date(2016, 1, 3), 53957],
#  ['34 ST-HERALD SQ', 'BDFMNQR', datetime.date(2016, 1, 4), 116171],
#  ['34 ST-HERALD SQ', 'BDFMNQR', datetime.date(2016, 1, 5), 115743],
#  ['34 ST-HERALD SQ', 'BDFMNQR', datetime.date(2016, 1, 6), 119404],
#  ['34 ST-HERALD SQ', 'BDFMNQR', datetime.date(2016, 1, 7), 118942],
#  ['34 ST-HERALD SQ', 'BDFMNQR', datetime.date(2016, 1, 8), 119808],
#  ['BEACH 67 ST', 'A', datetime.date(2016, 1, 2), 1251],
#  ['BEACH 67 ST', 'A', datetime.date(2016, 1, 3), 1006],
#  ['BEACH 67 ST', 'A', datetime.date(2016, 1, 4), 2386],
#  ['BEACH 67 ST', 'A', datetime.date(2016, 1, 5), 2198],
#  ['BEACH 67 ST', 'A', datetime.date(2016, 1, 6), 2376],
#  ['BEACH 67 ST', 'A', datetime.date(2016, 1, 7), 2355],
#  ['BEACH 67 ST', 'A', datetime.date(2016, 1, 8), 2408],
#  ['MORISN AV/SNDVW', '6', datetime.date(2016, 1, 2), 3822],
#  ['MORISN AV/SNDVW', '6', datetime.date(2016, 1, 3), 3149],
#  ['MORISN AV/SNDVW', '6', datetime.date(2016, 1, 4), 6267],
#  ['MORISN AV/SNDVW', '6', datetime.date(2016, 1, 5), 6161],
#  ['MORISN AV/SNDVW', '6', datetime.date(2016, 1, 6), 6674],
#  ['MORISN AV/SNDVW', '6', datetime.date(2016, 1, 7), 6868],
#  ['MORISN AV/SNDVW', '6', datetime.date(2016, 1, 8), 6820],
#  ['125 ST', '1', datetime.date(2016, 1, 2), 4745],
#  ['125 ST', '1', datetime.date(2016, 1, 3), 4200],
#  ['125 ST', '1', datetime.date(2016, 1, 4), 6906],
#  ['125 ST', '1', datetime.date(2016, 1, 5), 7022],
#  ['125 ST', '1', datetime.date(2016, 1, 6), 7395],
#  ['125 ST', '1', datetime.date(2016, 1, 7), 7598],
#  ['125 ST', '1', datetime.date(2016, 1, 8), 7476],
#  ['15 ST-PROSPECT', 'FG', datetime.date(2016, 1, 2), 3404],
#  ['15 ST-PROSPECT', 'FG', datetime.date(2016, 1, 3), 2747],
#  ['15 ST-PROSPECT', 'FG', datetime.date(2016, 1, 4), 6326],
#  ['15 ST-PROSPECT', 'FG', datetime.date(2016, 1, 5), 6391],
#  ['15 ST-PROSPECT', 'FG', datetime.date(2016, 1, 6), 6687],
#  ['15 ST-PROSPECT', 'FG', datetime.date(2016, 1, 7), 6749],
#  ['15 ST-PROSPECT', 'FG', datetime.date(2016, 1, 8), 6647],
#  ['RECTOR ST', '1', datetime.date(2016, 1, 2), 5014],
#  ['RECTOR ST', '1', datetime.date(2016, 1, 3), 3406],
#  ['RECTOR ST', '1', datetime.date(2016, 1, 4), 9568],
#  ['RECTOR ST', '1', datetime.date(2016, 1, 5), 10100],
#  ['RECTOR ST', '1', datetime.date(2016, 1, 6), 10448],
#  ['RECTOR ST', '1', datetime.date(2016, 1, 7), 10332],
#  ['RECTOR ST', '1', datetime.date(2016, 1, 8), 9964],
#  ['JAMAICA 179 ST', 'F', datetime.date(2016, 1, 2), 9622],
#  ['JAMAICA 179 ST', 'F', datetime.date(2016, 1, 3), 7428],
#  ['JAMAICA 179 ST', 'F', datetime.date(2016, 1, 4), 22994],
#  ['JAMAICA 179 ST', 'F', datetime.date(2016, 1, 5), 22753],
#  ['JAMAICA 179 ST', 'F', datetime.date(2016, 1, 6), 23743],
#  ['JAMAICA 179 ST', 'F', datetime.date(2016, 1, 7), 23709],
#  ['JAMAICA 179 ST', 'F', datetime.date(2016, 1, 8), 23220],
#  ['LONGWOOD AV', '6', datetime.date(2016, 1, 2), 1766],
#  ['LONGWOOD AV', '6', datetime.date(2016, 1, 3), 1543],
#  ['LONGWOOD AV', '6', datetime.date(2016, 1, 4), 3446],
#  ['LONGWOOD AV', '6', datetime.date(2016, 1, 5), 3447],
#  ['LONGWOOD AV', '6', datetime.date(2016, 1, 6), 3551],
#  ['LONGWOOD AV', '6', datetime.date(2016, 1, 7), 3629],
#  ['LONGWOOD AV', '6', datetime.date(2016, 1, 8), 3425],
#  ['MT EDEN AV', '4', datetime.date(2016, 1, 2), 3293],
#  ['MT EDEN AV', '4', datetime.date(2016, 1, 3), 2660],
#  ['MT EDEN AV', '4', datetime.date(2016, 1, 4), 5468],
#  ['MT EDEN AV', '4', datetime.date(2016, 1, 5), 5474],
#  ['MT EDEN AV', '4', datetime.date(2016, 1, 6), 5777],
#  ['MT EDEN AV', '4', datetime.date(2016, 1, 7), 5842],
#  ['MT EDEN AV', '4', datetime.date(2016, 1, 8), 5644],
#  ['207 ST', '1', datetime.date(2016, 1, 2), 4265],
#  ['207 ST', '1', datetime.date(2016, 1, 3), 3495],
#  ['207 ST', '1', datetime.date(2016, 1, 4), 6124],
#  ['207 ST', '1', datetime.date(2016, 1, 5), 5960],
#  ['207 ST', '1', datetime.date(2016, 1, 6), 6603],
#  ['207 ST', '1', datetime.date(2016, 1, 7), 6647],
#  ['207 ST', '1', datetime.date(2016, 1, 8), 6675],
#  ['WOODLAWN', '4', datetime.date(2016, 1, 2), 4285],
#  ['WOODLAWN', '4', datetime.date(2016, 1, 3), 3257],
#  ['WOODLAWN', '4', datetime.date(2016, 1, 4), 7094],
#  ['WOODLAWN', '4', datetime.date(2016, 1, 5), 6947],
#  ['WOODLAWN', '4', datetime.date(2016, 1, 6), 7489],
#  ['WOODLAWN', '4', datetime.date(2016, 1, 7), 7721],
#  ['WOODLAWN', '4', datetime.date(2016, 1, 8), 7441],
#  ['KOSCIUSZKO ST', 'J', datetime.date(2016, 1, 2), 3389],
#  ['KOSCIUSZKO ST', 'J', datetime.date(2016, 1, 3), 2762],
#  ['KOSCIUSZKO ST', 'J', datetime.date(2016, 1, 4), 4760],
#  ['KOSCIUSZKO ST', 'J', datetime.date(2016, 1, 5), 4632],
#  ['KOSCIUSZKO ST', 'J', datetime.date(2016, 1, 6), 4986],
#  ['KOSCIUSZKO ST', 'J', datetime.date(2016, 1, 7), 5109],
#  ['KOSCIUSZKO ST', 'J', datetime.date(2016, 1, 8), 4752],
#  ['LACKAWANNA', '1', datetime.date(2016, 1, 2), 1827],
#  ['LACKAWANNA', '1', datetime.date(2016, 1, 3), 1158],
#  ['LACKAWANNA', '1', datetime.date(2016, 1, 4), 8823],
#  ['LACKAWANNA', '1', datetime.date(2016, 1, 5), 8874],
#  ['LACKAWANNA', '1', datetime.date(2016, 1, 6), 9267],
#  ['LACKAWANNA', '1', datetime.date(2016, 1, 7), 9104],
#  ['LACKAWANNA', '1', datetime.date(2016, 1, 8), 8111],
#  ['BEACH 36 ST', 'A', datetime.date(2016, 1, 2), 528],
#  ['BEACH 36 ST', 'A', datetime.date(2016, 1, 3), 398],
#  ['BEACH 36 ST', 'A', datetime.date(2016, 1, 4), 972],
#  ['BEACH 36 ST', 'A', datetime.date(2016, 1, 5), 980],
#  ['BEACH 36 ST', 'A', datetime.date(2016, 1, 6), 1011],
#  ['BEACH 36 ST', 'A', datetime.date(2016, 1, 7), 978],
#  ['BEACH 36 ST', 'A', datetime.date(2016, 1, 8), 1013],
#  ['PENNSYLVANIA AV', '3', datetime.date(2016, 1, 2), 3922],
#  ['PENNSYLVANIA AV', '3', datetime.date(2016, 1, 3), 3194],
#  ['PENNSYLVANIA AV', '3', datetime.date(2016, 1, 4), 7519],
#  ['PENNSYLVANIA AV', '3', datetime.date(2016, 1, 5), 7300],
#  ['PENNSYLVANIA AV', '3', datetime.date(2016, 1, 6), 7766],
#  ['PENNSYLVANIA AV', '3', datetime.date(2016, 1, 7), 7927],
#  ['PENNSYLVANIA AV', '3', datetime.date(2016, 1, 8), 7822],
#  ['116 ST-COLUMBIA', '1', datetime.date(2016, 1, 2), 4568],
#  ['116 ST-COLUMBIA', '1', datetime.date(2016, 1, 3), 4212],
#  ['116 ST-COLUMBIA', '1', datetime.date(2016, 1, 4), 10080],
#  ['116 ST-COLUMBIA', '1', datetime.date(2016, 1, 5), 10634],
#  ['116 ST-COLUMBIA', '1', datetime.date(2016, 1, 6), 11209],
#  ['116 ST-COLUMBIA', '1', datetime.date(2016, 1, 7), 11277],
#  ['116 ST-COLUMBIA', '1', datetime.date(2016, 1, 8), 9753],
#  ['NOSTRAND AV', 'AC', datetime.date(2016, 1, 2), 11590],
#  ['NOSTRAND AV', 'AC', datetime.date(2016, 1, 3), 9161],
#  ['NOSTRAND AV', 'AC', datetime.date(2016, 1, 4), 16856],
#  ['NOSTRAND AV', 'AC', datetime.date(2016, 1, 5), 16841],
#  ['NOSTRAND AV', 'AC', datetime.date(2016, 1, 6), 17938],
#  ['NOSTRAND AV', 'AC', datetime.date(2016, 1, 7), 18184],
#  ['NOSTRAND AV', 'AC', datetime.date(2016, 1, 8), 18490],
#  ['225 ST', '25', datetime.date(2016, 1, 2), 2562],
#  ['225 ST', '25', datetime.date(2016, 1, 3), 2126],
#  ['225 ST', '25', datetime.date(2016, 1, 4), 4551],
#  ['225 ST', '25', datetime.date(2016, 1, 5), 4398],
#  ['225 ST', '25', datetime.date(2016, 1, 6), 4696],
#  ['225 ST', '25', datetime.date(2016, 1, 7), 4756],
#  ['225 ST', '25', datetime.date(2016, 1, 8), 4516],
#  ['CONEY IS-STILLW', 'DFNQ', datetime.date(2016, 1, 2), 7827],
#  ['CONEY IS-STILLW', 'DFNQ', datetime.date(2016, 1, 3), 6572],
#  ['CONEY IS-STILLW', 'DFNQ', datetime.date(2016, 1, 4), 11765],
#  ['CONEY IS-STILLW', 'DFNQ', datetime.date(2016, 1, 5), 11008],
#  ['CONEY IS-STILLW', 'DFNQ', datetime.date(2016, 1, 6), 11928],
#  ['CONEY IS-STILLW', 'DFNQ', datetime.date(2016, 1, 7), 12111],
#  ['CONEY IS-STILLW', 'DFNQ', datetime.date(2016, 1, 8), 11455],
#  ['174-175 STS', 'BD', datetime.date(2016, 1, 2), 3419],
#  ['174-175 STS', 'BD', datetime.date(2016, 1, 3), 2728],
#  ['174-175 STS', 'BD', datetime.date(2016, 1, 4), 5408],
#  ['174-175 STS', 'BD', datetime.date(2016, 1, 5), 5195],
#  ['174-175 STS', 'BD', datetime.date(2016, 1, 6), 5400],
#  ['174-175 STS', 'BD', datetime.date(2016, 1, 7), 5593],
#  ['174-175 STS', 'BD', datetime.date(2016, 1, 8), 5445],
#  ['116 ST', '6', datetime.date(2016, 1, 2), 7467],
#  ['116 ST', '6', datetime.date(2016, 1, 3), 6078],
#  ['116 ST', '6', datetime.date(2016, 1, 4), 16098],
#  ['116 ST', '6', datetime.date(2016, 1, 5), 15774],
#  ['116 ST', '6', datetime.date(2016, 1, 6), 17560],
#  ['116 ST', '6', datetime.date(2016, 1, 7), 16861],
#  ['116 ST', '6', datetime.date(2016, 1, 8), 14836],
#  ['KINGSBRIDGE RD', 'BD', datetime.date(2016, 1, 2), 4576],
#  ['KINGSBRIDGE RD', 'BD', datetime.date(2016, 1, 3), 3950],
#  ['KINGSBRIDGE RD', 'BD', datetime.date(2016, 1, 4), 7567],
#  ['KINGSBRIDGE RD', 'BD', datetime.date(2016, 1, 5), 7625],
#  ['KINGSBRIDGE RD', 'BD', datetime.date(2016, 1, 6), 8018],
#  ['KINGSBRIDGE RD', 'BD', datetime.date(2016, 1, 7), 8034],
#  ['KINGSBRIDGE RD', 'BD', datetime.date(2016, 1, 8), 7589],
#  ['30 AV', 'NQ', datetime.date(2016, 1, 2), 9553],
#  ['30 AV', 'NQ', datetime.date(2016, 1, 3), 7120],
#  ['30 AV', 'NQ', datetime.date(2016, 1, 4), 14088],
#  ['30 AV', 'NQ', datetime.date(2016, 1, 5), 13579],
#  ['30 AV', 'NQ', datetime.date(2016, 1, 6), 14248],
#  ['30 AV', 'NQ', datetime.date(2016, 1, 7), 14439],
#  ['30 AV', 'NQ', datetime.date(2016, 1, 8), 14582],
#  ['FORDHAM RD', 'BD', datetime.date(2016, 1, 2), 7371],
#  ['FORDHAM RD', 'BD', datetime.date(2016, 1, 3), 5524],
#  ['FORDHAM RD', 'BD', datetime.date(2016, 1, 4), 11435],
#  ['FORDHAM RD', 'BD', datetime.date(2016, 1, 5), 11049],
#  ['FORDHAM RD', 'BD', datetime.date(2016, 1, 6), 11670],
#  ['FORDHAM RD', 'BD', datetime.date(2016, 1, 7), 11634],
#  ['FORDHAM RD', 'BD', datetime.date(2016, 1, 8), 11752],
#  ['NORWOOD AV', 'JZ', datetime.date(2016, 1, 2), 2055],
#  ['NORWOOD AV', 'JZ', datetime.date(2016, 1, 3), 1749],
#  ['NORWOOD AV', 'JZ', datetime.date(2016, 1, 4), 3481],
#  ['NORWOOD AV', 'JZ', datetime.date(2016, 1, 5), 3084],
#  ['NORWOOD AV', 'JZ', datetime.date(2016, 1, 6), 3627],
#  ['NORWOOD AV', 'JZ', datetime.date(2016, 1, 7), 3623],
#  ['NORWOOD AV', 'JZ', datetime.date(2016, 1, 8), 3520],
#  ['8 ST-NYU', 'NR', datetime.date(2016, 1, 2), 11988],
#  ['8 ST-NYU', 'NR', datetime.date(2016, 1, 3), 8938],
#  ['8 ST-NYU', 'NR', datetime.date(2016, 1, 4), 15200],
#  ['8 ST-NYU', 'NR', datetime.date(2016, 1, 5), 15063],
#  ['8 ST-NYU', 'NR', datetime.date(2016, 1, 6), 16004],
#  ['8 ST-NYU', 'NR', datetime.date(2016, 1, 7), 16577],
#  ['8 ST-NYU', 'NR', datetime.date(2016, 1, 8), 15399],
#  ['KEW GARDENS', 'EF', datetime.date(2016, 1, 2), 12152],
#  ['KEW GARDENS', 'EF', datetime.date(2016, 1, 3), 9879],
#  ['KEW GARDENS', 'EF', datetime.date(2016, 1, 4), 26629],
#  ['KEW GARDENS', 'EF', datetime.date(2016, 1, 5), 26908],
#  ['KEW GARDENS', 'EF', datetime.date(2016, 1, 6), 27810],
#  ['KEW GARDENS', 'EF', datetime.date(2016, 1, 7), 27972],
#  ['KEW GARDENS', 'EF', datetime.date(2016, 1, 8), 26100],
#  ['FLUSHING AV', 'G', datetime.date(2016, 1, 2), 1266],
#  ['FLUSHING AV', 'G', datetime.date(2016, 1, 3), 1310],
#  ['FLUSHING AV', 'G', datetime.date(2016, 1, 4), 2866],
#  ['FLUSHING AV', 'G', datetime.date(2016, 1, 5), 2745],
#  ['FLUSHING AV', 'G', datetime.date(2016, 1, 6), 2949],
#  ['FLUSHING AV', 'G', datetime.date(2016, 1, 7), 2804],
#  ['FLUSHING AV', 'G', datetime.date(2016, 1, 8), 2678],
#  ["B'WAY-LAFAYETTE", 'BDFQ6', datetime.date(2016, 1, 2), 15413],
#  ["B'WAY-LAFAYETTE", 'BDFQ6', datetime.date(2016, 1, 3), 11587],
#  ["B'WAY-LAFAYETTE", 'BDFQ6', datetime.date(2016, 1, 4), 21655],
#  ["B'WAY-LAFAYETTE", 'BDFQ6', datetime.date(2016, 1, 5), 22153],
#  ["B'WAY-LAFAYETTE", 'BDFQ6', datetime.date(2016, 1, 6), 23115],
#  ["B'WAY-LAFAYETTE", 'BDFQ6', datetime.date(2016, 1, 7), 23537],
#  ["B'WAY-LAFAYETTE", 'BDFQ6', datetime.date(2016, 1, 8), 19846],
#  ['CYPRESS HILLS', 'J', datetime.date(2016, 1, 2), 737],
#  ['CYPRESS HILLS', 'J', datetime.date(2016, 1, 3), 589],
#  ['CYPRESS HILLS', 'J', datetime.date(2016, 1, 4), 1445],
#  ['CYPRESS HILLS', 'J', datetime.date(2016, 1, 5), 1123],
#  ['CYPRESS HILLS', 'J', datetime.date(2016, 1, 6), 1466],
#  ['CYPRESS HILLS', 'J', datetime.date(2016, 1, 7), 1399],
#  ['CYPRESS HILLS', 'J', datetime.date(2016, 1, 8), 1408],
#  ['77 ST', '6', datetime.date(2016, 1, 2), 6042],
#  ['77 ST', '6', datetime.date(2016, 1, 3), 4583],
#  ['77 ST', '6', datetime.date(2016, 1, 4), 34866],
#  ['77 ST', '6', datetime.date(2016, 1, 5), 36433],
#  ['77 ST', '6', datetime.date(2016, 1, 6), 37685],
#  ['77 ST', '6', datetime.date(2016, 1, 7), 37685],
#  ['77 ST', '6', datetime.date(2016, 1, 8), 29088],
#  ['BEDFORD AV', 'L', datetime.date(2016, 1, 2), 23883],
#  ['BEDFORD AV', 'L', datetime.date(2016, 1, 3), 17191],
#  ['BEDFORD AV', 'L', datetime.date(2016, 1, 4), 22410],
#  ['BEDFORD AV', 'L', datetime.date(2016, 1, 5), 22739],
#  ['BEDFORD AV', 'L', datetime.date(2016, 1, 6), 24499],
#  ['BEDFORD AV', 'L', datetime.date(2016, 1, 7), 25481],
#  ['BEDFORD AV', 'L', datetime.date(2016, 1, 8), 26090],
#  ['METS-WILLETS PT', '7', datetime.date(2016, 1, 2), 1157],
#  ['METS-WILLETS PT', '7', datetime.date(2016, 1, 3), 1050],
#  ['METS-WILLETS PT', '7', datetime.date(2016, 1, 4), 2068],
#  ['METS-WILLETS PT', '7', datetime.date(2016, 1, 5), 1989],
#  ['METS-WILLETS PT', '7', datetime.date(2016, 1, 6), 2171],
#  ['METS-WILLETS PT', '7', datetime.date(2016, 1, 7), 2448],
#  ['METS-WILLETS PT', '7', datetime.date(2016, 1, 8), 1959],
#  ['FAR ROCKAWAY', 'A', datetime.date(2016, 1, 2), 2764],
#  ['FAR ROCKAWAY', 'A', datetime.date(2016, 1, 3), 2207],
#  ['FAR ROCKAWAY', 'A', datetime.date(2016, 1, 4), 4845],
#  ['FAR ROCKAWAY', 'A', datetime.date(2016, 1, 5), 4803],
#  ['FAR ROCKAWAY', 'A', datetime.date(2016, 1, 6), 5112],
#  ['FAR ROCKAWAY', 'A', datetime.date(2016, 1, 7), 5219],
#  ['FAR ROCKAWAY', 'A', datetime.date(2016, 1, 8), 5180],
#  ['CANARSIE-ROCKAW', 'L', datetime.date(2016, 1, 2), 6178],
#  ['CANARSIE-ROCKAW', 'L', datetime.date(2016, 1, 3), 4990],
#  ['CANARSIE-ROCKAW', 'L', datetime.date(2016, 1, 4), 13058],
#  ['CANARSIE-ROCKAW', 'L', datetime.date(2016, 1, 5), 12635],
#  ['CANARSIE-ROCKAW', 'L', datetime.date(2016, 1, 6), 13516],
#  ['CANARSIE-ROCKAW', 'L', datetime.date(2016, 1, 7), 13895],
#  ['CANARSIE-ROCKAW', 'L', datetime.date(2016, 1, 8), 13023],
#  ['175 ST', 'A', datetime.date(2016, 1, 2), 7907],
#  ['175 ST', 'A', datetime.date(2016, 1, 3), 6184],
#  ['175 ST', 'A', datetime.date(2016, 1, 4), 11929],
#  ['175 ST', 'A', datetime.date(2016, 1, 5), 12450],
#  ['175 ST', 'A', datetime.date(2016, 1, 6), 12972],
#  ['175 ST', 'A', datetime.date(2016, 1, 7), 13189],
#  ['175 ST', 'A', datetime.date(2016, 1, 8), 13340],
#  ['LAFAYETTE AV', 'C', datetime.date(2016, 1, 2), 3591],
#  ['LAFAYETTE AV', 'C', datetime.date(2016, 1, 3), 2896],
#  ['LAFAYETTE AV', 'C', datetime.date(2016, 1, 4), 4916],
#  ['LAFAYETTE AV', 'C', datetime.date(2016, 1, 5), 4560],
#  ['LAFAYETTE AV', 'C', datetime.date(2016, 1, 6), 5085],
#  ['LAFAYETTE AV', 'C', datetime.date(2016, 1, 7), 4992],
#  ['LAFAYETTE AV', 'C', datetime.date(2016, 1, 8), 4431],
#  ['CANAL ST', 'ACE', datetime.date(2016, 1, 2), 8049],
#  ['CANAL ST', 'ACE', datetime.date(2016, 1, 3), 5911],
#  ['CANAL ST', 'ACE', datetime.date(2016, 1, 4), 18515],
#  ['CANAL ST', 'ACE', datetime.date(2016, 1, 5), 19066],
#  ['CANAL ST', 'ACE', datetime.date(2016, 1, 6), 19727],
#  ['CANAL ST', 'ACE', datetime.date(2016, 1, 7), 20079],
#  ['CANAL ST', 'ACE', datetime.date(2016, 1, 8), 18925],
#  ['4AV-9 ST', 'DFGMNR', datetime.date(2016, 1, 2), 5612],
#  ['4AV-9 ST', 'DFGMNR', datetime.date(2016, 1, 3), 4224],
#  ['4AV-9 ST', 'DFGMNR', datetime.date(2016, 1, 4), 9042],
#  ['4AV-9 ST', 'DFGMNR', datetime.date(2016, 1, 5), 9114],
#  ['4AV-9 ST', 'DFGMNR', datetime.date(2016, 1, 6), 9467],
#  ['4AV-9 ST', 'DFGMNR', datetime.date(2016, 1, 7), 9551],
#  ['4AV-9 ST', 'DFGMNR', datetime.date(2016, 1, 8), 9444],
#  ['HOWARD BCH JFK', 'A', datetime.date(2016, 1, 2), 2702],
#  ['HOWARD BCH JFK', 'A', datetime.date(2016, 1, 3), 2894],
#  ['HOWARD BCH JFK', 'A', datetime.date(2016, 1, 4), 4961],
#  ['HOWARD BCH JFK', 'A', datetime.date(2016, 1, 5), 4590],
#  ['HOWARD BCH JFK', 'A', datetime.date(2016, 1, 6), 4702],
#  ['HOWARD BCH JFK', 'A', datetime.date(2016, 1, 7), 4574],
#  ['HOWARD BCH JFK', 'A', datetime.date(2016, 1, 8), 3928],
#  ['EAST 105 ST', 'L', datetime.date(2016, 1, 2), 1785],
#  ['EAST 105 ST', 'L', datetime.date(2016, 1, 3), 1456],
#  ['EAST 105 ST', 'L', datetime.date(2016, 1, 4), 4019],
#  ['EAST 105 ST', 'L', datetime.date(2016, 1, 5), 4116],
#  ['EAST 105 ST', 'L', datetime.date(2016, 1, 6), 4183],
#  ['EAST 105 ST', 'L', datetime.date(2016, 1, 7), 4339],
#  ['EAST 105 ST', 'L', datetime.date(2016, 1, 8), 4134],
#  ['170 ST', 'BD', datetime.date(2016, 1, 2), 4440],
#  ['170 ST', 'BD', datetime.date(2016, 1, 3), 3764],
#  ['170 ST', 'BD', datetime.date(2016, 1, 4), 7047],
#  ['170 ST', 'BD', datetime.date(2016, 1, 5), 6722],
#  ['170 ST', 'BD', datetime.date(2016, 1, 6), 2187],
#  ['BOROUGH HALL', '2345R', datetime.date(2016, 1, 2), 11878],
#  ['BOROUGH HALL', '2345R', datetime.date(2016, 1, 3), 8799],
#  ['BOROUGH HALL', '2345R', datetime.date(2016, 1, 4), 34317],
#  ['BOROUGH HALL', '2345R', datetime.date(2016, 1, 5), 34798],
#  ['BOROUGH HALL', '2345R', datetime.date(2016, 1, 6), 37110],
#  ['BOROUGH HALL', '2345R', datetime.date(2016, 1, 7), 36639],
#  ['BOROUGH HALL', '2345R', datetime.date(2016, 1, 8), 35087],
#  ['135 ST', '23', datetime.date(2016, 1, 2), 9764],
#  ['135 ST', '23', datetime.date(2016, 1, 3), 8415],
#  ['135 ST', '23', datetime.date(2016, 1, 4), 14855],
#  ['135 ST', '23', datetime.date(2016, 1, 5), 15052],
#  ['135 ST', '23', datetime.date(2016, 1, 6), 16257],
#  ['135 ST', '23', datetime.date(2016, 1, 7), 16059],
#  ['135 ST', '23', datetime.date(2016, 1, 8), 16035],
#  ['WOODHAVEN BLVD', 'JZ', datetime.date(2016, 1, 2), 2871],
#  ['WOODHAVEN BLVD', 'JZ', datetime.date(2016, 1, 3), 2324],
#  ['WOODHAVEN BLVD', 'JZ', datetime.date(2016, 1, 4), 4798],
#  ['WOODHAVEN BLVD', 'JZ', datetime.date(2016, 1, 5), 3670],
#  ['WOODHAVEN BLVD', 'JZ', datetime.date(2016, 1, 6), 4979],
#  ['WOODHAVEN BLVD', 'JZ', datetime.date(2016, 1, 7), 4844],
#  ['WOODHAVEN BLVD', 'JZ', datetime.date(2016, 1, 8), 4947],
#  ['KINGSBRIDGE RD', '4', datetime.date(2016, 1, 2), 5266],
#  ['KINGSBRIDGE RD', '4', datetime.date(2016, 1, 3), 4523],
#  ['KINGSBRIDGE RD', '4', datetime.date(2016, 1, 4), 9304],
#  ['KINGSBRIDGE RD', '4', datetime.date(2016, 1, 5), 9134],
#  ['KINGSBRIDGE RD', '4', datetime.date(2016, 1, 6), 9800],
#  ['KINGSBRIDGE RD', '4', datetime.date(2016, 1, 7), 9805],
#  ['KINGSBRIDGE RD', '4', datetime.date(2016, 1, 8), 9182],
#  ['ROOSEVELT ISLND', 'F', datetime.date(2016, 1, 2), 3877],
#  ['ROOSEVELT ISLND', 'F', datetime.date(2016, 1, 3), 3431],
#  ['ROOSEVELT ISLND', 'F', datetime.date(2016, 1, 4), 5682],
#  ['ROOSEVELT ISLND', 'F', datetime.date(2016, 1, 5), 5842],
#  ['ROOSEVELT ISLND', 'F', datetime.date(2016, 1, 6), 6104],
#  ['ROOSEVELT ISLND', 'F', datetime.date(2016, 1, 7), 5983],
#  ['ROOSEVELT ISLND', 'F', datetime.date(2016, 1, 8), 6027],
#  ['75 AV', 'EF', datetime.date(2016, 1, 2), 947],
#  ['75 AV', 'EF', datetime.date(2016, 1, 3), 687],
#  ['75 AV', 'EF', datetime.date(2016, 1, 4), 3549],
#  ['75 AV', 'EF', datetime.date(2016, 1, 5), 3701],
#  ['75 AV', 'EF', datetime.date(2016, 1, 6), 3730],
#  ['75 AV', 'EF', datetime.date(2016, 1, 7), 3840],
#  ['75 AV', 'EF', datetime.date(2016, 1, 8), 3729],
#  ['137 ST CITY COL', '1', datetime.date(2016, 1, 2), 8317],
#  ['137 ST CITY COL', '1', datetime.date(2016, 1, 3), 6846],
#  ['137 ST CITY COL', '1', datetime.date(2016, 1, 4), 12589],
#  ['137 ST CITY COL', '1', datetime.date(2016, 1, 5), 12699],
#  ['137 ST CITY COL', '1', datetime.date(2016, 1, 6), 13247],
#  ['137 ST CITY COL', '1', datetime.date(2016, 1, 7), 13255],
#  ['137 ST CITY COL', '1', datetime.date(2016, 1, 8), 12568],
#  ['GRAHAM AV', 'L', datetime.date(2016, 1, 2), 6309],
#  ['GRAHAM AV', 'L', datetime.date(2016, 1, 3), 4702],
#  ['GRAHAM AV', 'L', datetime.date(2016, 1, 4), 9919],
#  ['GRAHAM AV', 'L', datetime.date(2016, 1, 5), 10164],
#  ['GRAHAM AV', 'L', datetime.date(2016, 1, 6), 10369],
#  ['GRAHAM AV', 'L', datetime.date(2016, 1, 7), 10642],
#  ['GRAHAM AV', 'L', datetime.date(2016, 1, 8), 10871],
#  ['FLUSHING AV', 'JM', datetime.date(2016, 1, 2), 5624],
#  ['FLUSHING AV', 'JM', datetime.date(2016, 1, 3), 4415],
#  ['FLUSHING AV', 'JM', datetime.date(2016, 1, 4), 9382],
#  ['FLUSHING AV', 'JM', datetime.date(2016, 1, 5), 8901],
#  ['FLUSHING AV', 'JM', datetime.date(2016, 1, 6), 9463],
#  ['FLUSHING AV', 'JM', datetime.date(2016, 1, 7), 9465],
#  ['FLUSHING AV', 'JM', datetime.date(2016, 1, 8), 8880],
#  ['HOYT ST', '23', datetime.date(2016, 1, 2), 4318],
#  ['HOYT ST', '23', datetime.date(2016, 1, 3), 3450],
#  ['HOYT ST', '23', datetime.date(2016, 1, 4), 7785],
#  ['HOYT ST', '23', datetime.date(2016, 1, 5), 7485],
#  ['HOYT ST', '23', datetime.date(2016, 1, 6), 7942],
#  ['HOYT ST', '23', datetime.date(2016, 1, 7), 7723],
#  ['HOYT ST', '23', datetime.date(2016, 1, 8), 7734],
#  ['50 ST', 'D', datetime.date(2016, 1, 2), 1309],
#  ['50 ST', 'D', datetime.date(2016, 1, 3), 1614],
#  ['50 ST', 'D', datetime.date(2016, 1, 4), 3294],
#  ['50 ST', 'D', datetime.date(2016, 1, 5), 3196],
#  ['50 ST', 'D', datetime.date(2016, 1, 6), 3496],
#  ['50 ST', 'D', datetime.date(2016, 1, 7), 3481],
#  ['50 ST', 'D', datetime.date(2016, 1, 8), 3053],
#  ['INTERVALE AV', '25', datetime.date(2016, 1, 2), 1755],
#  ['INTERVALE AV', '25', datetime.date(2016, 1, 3), 1418],
#  ['INTERVALE AV', '25', datetime.date(2016, 1, 4), 3365],
#  ['INTERVALE AV', '25', datetime.date(2016, 1, 5), 3243],
#  ['INTERVALE AV', '25', datetime.date(2016, 1, 6), 3647],
#  ['INTERVALE AV', '25', datetime.date(2016, 1, 7), 3631],
#  ['INTERVALE AV', '25', datetime.date(2016, 1, 8), 3448],
#  ['21 ST', 'G', datetime.date(2016, 1, 2), 983],
#  ['21 ST', 'G', datetime.date(2016, 1, 3), 960],
#  ['21 ST', 'G', datetime.date(2016, 1, 4), 1905],
#  ['21 ST', 'G', datetime.date(2016, 1, 5), 1514],
#  ['21 ST', 'G', datetime.date(2016, 1, 6), 1655],
#  ['21 ST', 'G', datetime.date(2016, 1, 7), 1700],
#  ['21 ST', 'G', datetime.date(2016, 1, 8), 1542],
#  ['CATHEDRAL PKWY', 'BC', datetime.date(2016, 1, 2), 4336],
#  ['CATHEDRAL PKWY', 'BC', datetime.date(2016, 1, 3), 3694],
#  ['CATHEDRAL PKWY', 'BC', datetime.date(2016, 1, 4), 6790],
#  ['CATHEDRAL PKWY', 'BC', datetime.date(2016, 1, 5), 6973],
#  ['CATHEDRAL PKWY', 'BC', datetime.date(2016, 1, 6), 7221],
#  ['CATHEDRAL PKWY', 'BC', datetime.date(2016, 1, 7), 7193],
#  ['CATHEDRAL PKWY', 'BC', datetime.date(2016, 1, 8), 6809],
#  ['174 ST', '25', datetime.date(2016, 1, 2), 3821],
#  ['174 ST', '25', datetime.date(2016, 1, 3), 3066],
#  ['174 ST', '25', datetime.date(2016, 1, 4), 6221],
#  ['174 ST', '25', datetime.date(2016, 1, 5), 5877],
#  ['174 ST', '25', datetime.date(2016, 1, 6), 6374],
#  ['174 ST', '25', datetime.date(2016, 1, 7), 6555],
#  ['174 ST', '25', datetime.date(2016, 1, 8), 7762],
#  ['PROSPECT AV', '25', datetime.date(2016, 1, 2), 4465],
#  ['PROSPECT AV', '25', datetime.date(2016, 1, 3), 3673],
#  ['PROSPECT AV', '25', datetime.date(2016, 1, 4), 8075],
#  ['PROSPECT AV', '25', datetime.date(2016, 1, 5), 7865],
#  ['PROSPECT AV', '25', datetime.date(2016, 1, 6), 8277],
#  ['PROSPECT AV', '25', datetime.date(2016, 1, 7), 8278],
#  ['PROSPECT AV', '25', datetime.date(2016, 1, 8), 7929],
#  ['PROSPECT PARK', 'BQS', datetime.date(2016, 1, 2), 6406],
#  ['PROSPECT PARK', 'BQS', datetime.date(2016, 1, 3), 5073],
#  ['PROSPECT PARK', 'BQS', datetime.date(2016, 1, 4), 9145],
#  ['PROSPECT PARK', 'BQS', datetime.date(2016, 1, 5), 9192],
#  ['PROSPECT PARK', 'BQS', datetime.date(2016, 1, 6), 9761],
#  ['PROSPECT PARK', 'BQS', datetime.date(2016, 1, 7), 9705],
#  ['PROSPECT PARK', 'BQS', datetime.date(2016, 1, 8), 9826],
#  ['34 ST-PENN STA', '123', datetime.date(2016, 1, 2), 18203],
#  ['34 ST-PENN STA', '123', datetime.date(2016, 1, 3), 13136],
#  ['34 ST-PENN STA', '123', datetime.date(2016, 1, 4), 35274],
#  ['34 ST-PENN STA', '123', datetime.date(2016, 1, 5), 37413],
#  ['34 ST-PENN STA', '123', datetime.date(2016, 1, 6), 36958],
#  ['34 ST-PENN STA', '123', datetime.date(2016, 1, 7), 36570],
#  ['34 ST-PENN STA', '123', datetime.date(2016, 1, 8), 34152],
#  ['TREMONT AV', 'BD', datetime.date(2016, 1, 2), 5675],
#  ['TREMONT AV', 'BD', datetime.date(2016, 1, 3), 4723],
#  ['TREMONT AV', 'BD', datetime.date(2016, 1, 4), 9712],
#  ['TREMONT AV', 'BD', datetime.date(2016, 1, 5), 9643],
#  ['TREMONT AV', 'BD', datetime.date(2016, 1, 6), 10072],
#  ['TREMONT AV', 'BD', datetime.date(2016, 1, 7), 10147],
#  ['TREMONT AV', 'BD', datetime.date(2016, 1, 8), 9873],
#  ['E 149 ST', '6', datetime.date(2016, 1, 2), 2682],
#  ['E 149 ST', '6', datetime.date(2016, 1, 3), 2288],
#  ['E 149 ST', '6', datetime.date(2016, 1, 4), 4767],
#  ['E 149 ST', '6', datetime.date(2016, 1, 5), 4810],
#  ['E 149 ST', '6', datetime.date(2016, 1, 6), 5018],
#  ['E 149 ST', '6', datetime.date(2016, 1, 7), 5017],
#  ['E 149 ST', '6', datetime.date(2016, 1, 8), 4723],
#  ['79 ST', 'D', datetime.date(2016, 1, 2), 3374],
#  ['79 ST', 'D', datetime.date(2016, 1, 3), 2977],
#  ['79 ST', 'D', datetime.date(2016, 1, 4), 6947],
#  ['79 ST', 'D', datetime.date(2016, 1, 5), 6919],
#  ['79 ST', 'D', datetime.date(2016, 1, 6), 7177],
#  ['79 ST', 'D', datetime.date(2016, 1, 7), 7262],
#  ['79 ST', 'D', datetime.date(2016, 1, 8), 7089],
#  ['110 ST', '6', datetime.date(2016, 1, 2), 5355],
#  ['110 ST', '6', datetime.date(2016, 1, 3), 4133],
#  ['110 ST', '6', datetime.date(2016, 1, 4), 12187],
#  ['110 ST', '6', datetime.date(2016, 1, 5), 12245],
#  ['110 ST', '6', datetime.date(2016, 1, 6), 13265],
#  ['110 ST', '6', datetime.date(2016, 1, 7), 12944],
#  ['110 ST', '6', datetime.date(2016, 1, 8), 12216],
#  ['EUCLID AV', 'AC', datetime.date(2016, 1, 2), 13197],
#  ['EUCLID AV', 'AC', datetime.date(2016, 1, 3), 10440],
#  ['EUCLID AV', 'AC', datetime.date(2016, 1, 4), 9805],
#  ['EUCLID AV', 'AC', datetime.date(2016, 1, 5), 9541],
#  ['EUCLID AV', 'AC', datetime.date(2016, 1, 6), 9930],
#  ['EUCLID AV', 'AC', datetime.date(2016, 1, 7), 9944],
#  ['EUCLID AV', 'AC', datetime.date(2016, 1, 8), 11730],
#  ['135 ST', 'BC', datetime.date(2016, 1, 2), 2554],
#  ['135 ST', 'BC', datetime.date(2016, 1, 3), 2078],
#  ['135 ST', 'BC', datetime.date(2016, 1, 4), 5045],
#  ['135 ST', 'BC', datetime.date(2016, 1, 5), 5431],
#  ['135 ST', 'BC', datetime.date(2016, 1, 6), 5629],
#  ['135 ST', 'BC', datetime.date(2016, 1, 7), 5510],
#  ['135 ST', 'BC', datetime.date(2016, 1, 8), 5228],
#  ['INWOOD-207 ST', 'A', datetime.date(2016, 1, 2), 5471],
#  ['INWOOD-207 ST', 'A', datetime.date(2016, 1, 3), 4398],
#  ['INWOOD-207 ST', 'A', datetime.date(2016, 1, 4), 9091],
#  ['INWOOD-207 ST', 'A', datetime.date(2016, 1, 5), 9130],
#  ['INWOOD-207 ST', 'A', datetime.date(2016, 1, 6), 9466],
#  ['INWOOD-207 ST', 'A', datetime.date(2016, 1, 7), 9639],
#  ['INWOOD-207 ST', 'A', datetime.date(2016, 1, 8), 9210],
#  ['CHAMBERS ST', 'JZ456', datetime.date(2016, 1, 2), 3571],
#  ['CHAMBERS ST', 'JZ456', datetime.date(2016, 1, 3), 2497],
#  ['CHAMBERS ST', 'JZ456', datetime.date(2016, 1, 4), 11211],
#  ['CHAMBERS ST', 'JZ456', datetime.date(2016, 1, 5), 11586],
#  ['CHAMBERS ST', 'JZ456', datetime.date(2016, 1, 6), 12176],
#  ['CHAMBERS ST', 'JZ456', datetime.date(2016, 1, 7), 12053],
#  ['CHAMBERS ST', 'JZ456', datetime.date(2016, 1, 8), 10853],
#  ['161/YANKEE STAD', 'BD4', datetime.date(2016, 1, 2), 8317],
#  ['161/YANKEE STAD', 'BD4', datetime.date(2016, 1, 3), 6606],
#  ['161/YANKEE STAD', 'BD4', datetime.date(2016, 1, 4), 13211],
#  ['161/YANKEE STAD', 'BD4', datetime.date(2016, 1, 5), 12505],
#  ['161/YANKEE STAD', 'BD4', datetime.date(2016, 1, 6), 13154],
#  ['161/YANKEE STAD', 'BD4', datetime.date(2016, 1, 7), 13335],
#  ['161/YANKEE STAD', 'BD4', datetime.date(2016, 1, 8), 15088],
#  ['CHURCH AV', 'BQ', datetime.date(2016, 1, 2), 10284],
#  ['CHURCH AV', 'BQ', datetime.date(2016, 1, 3), 8198],
#  ['CHURCH AV', 'BQ', datetime.date(2016, 1, 4), 16848],
#  ['CHURCH AV', 'BQ', datetime.date(2016, 1, 5), 16536],
#  ['CHURCH AV', 'BQ', datetime.date(2016, 1, 6), 17450],
#  ['CHURCH AV', 'BQ', datetime.date(2016, 1, 7), 17512],
#  ['CHURCH AV', 'BQ', datetime.date(2016, 1, 8), 17714],
#  ['66 ST-LINCOLN', '1', datetime.date(2016, 1, 2), 17524],
#  ['66 ST-LINCOLN', '1', datetime.date(2016, 1, 3), 12360],
#  ['66 ST-LINCOLN', '1', datetime.date(2016, 1, 4), 24429],
#  ['66 ST-LINCOLN', '1', datetime.date(2016, 1, 5), 24945],
#  ['66 ST-LINCOLN', '1', datetime.date(2016, 1, 6), 25960],
#  ['66 ST-LINCOLN', '1', datetime.date(2016, 1, 7), 26132],
#  ['66 ST-LINCOLN', '1', datetime.date(2016, 1, 8), 20711],
#  ['PELHAM PKWY', '25', datetime.date(2016, 1, 2), 5698],
#  ['PELHAM PKWY', '25', datetime.date(2016, 1, 3), 4419],
#  ['PELHAM PKWY', '25', datetime.date(2016, 1, 4), 9618],
#  ['PELHAM PKWY', '25', datetime.date(2016, 1, 5), 9157],
#  ['PELHAM PKWY', '25', datetime.date(2016, 1, 6), 9836],
#  ['PELHAM PKWY', '25', datetime.date(2016, 1, 7), 9786],
#  ['PELHAM PKWY', '25', datetime.date(2016, 1, 8), 9305],
#  ['KINGSTON AV', '3', datetime.date(2016, 1, 2), 3028],
#  ['KINGSTON AV', '3', datetime.date(2016, 1, 3), 2958],
#  ['KINGSTON AV', '3', datetime.date(2016, 1, 4), 5208],
#  ['KINGSTON AV', '3', datetime.date(2016, 1, 5), 5060],
#  ['KINGSTON AV', '3', datetime.date(2016, 1, 6), 5079],
#  ['KINGSTON AV', '3', datetime.date(2016, 1, 7), 5107],
#  ['KINGSTON AV', '3', datetime.date(2016, 1, 8), 5120],
#  ['14TH STREET', '1', datetime.date(2016, 1, 2), 5376],
#  ['14TH STREET', '1', datetime.date(2016, 1, 3), 3705],
#  ['14TH STREET', '1', datetime.date(2016, 1, 4), 8363],
#  ['14TH STREET', '1', datetime.date(2016, 1, 5), 8739],
#  ['14TH STREET', '1', datetime.date(2016, 1, 6), 8897],
#  ['14TH STREET', '1', datetime.date(2016, 1, 7), 9029],
#  ['14TH STREET', '1', datetime.date(2016, 1, 8), 8471],
#  ['125 ST', '456', datetime.date(2016, 1, 2), 13505],
#  ['125 ST', '456', datetime.date(2016, 1, 3), 11337],
#  ['125 ST', '456', datetime.date(2016, 1, 4), 23883],
#  ['125 ST', '456', datetime.date(2016, 1, 5), 23847],
#  ['125 ST', '456', datetime.date(2016, 1, 6), 25381],
#  ['125 ST', '456', datetime.date(2016, 1, 7), 25394],
#  ['125 ST', '456', datetime.date(2016, 1, 8), 28430],
#  ['BAYCHESTER AV', '5', datetime.date(2016, 1, 2), 1571],
#  ['BAYCHESTER AV', '5', datetime.date(2016, 1, 3), 1187],
#  ['BAYCHESTER AV', '5', datetime.date(2016, 1, 4), 4292],
#  ['BAYCHESTER AV', '5', datetime.date(2016, 1, 5), 4111],
#  ['BAYCHESTER AV', '5', datetime.date(2016, 1, 6), 4482],
#  ['BAYCHESTER AV', '5', datetime.date(2016, 1, 7), 4525],
#  ['BAYCHESTER AV', '5', datetime.date(2016, 1, 8), 4430],
#  ['JUNCTION BLVD', '7', datetime.date(2016, 1, 2), 17004],
#  ['JUNCTION BLVD', '7', datetime.date(2016, 1, 3), 14765],
#  ['JUNCTION BLVD', '7', datetime.date(2016, 1, 4), 20988],
#  ['JUNCTION BLVD', '7', datetime.date(2016, 1, 5), 19807],
#  ['JUNCTION BLVD', '7', datetime.date(2016, 1, 6), 21783],
#  ['JUNCTION BLVD', '7', datetime.date(2016, 1, 7), 22148],
#  ['JUNCTION BLVD', '7', datetime.date(2016, 1, 8), 22527],
#  ['59 ST COLUMBUS', '1ABCD', datetime.date(2016, 1, 2), 7104],
#  ['59 ST COLUMBUS', '1ABCD', datetime.date(2016, 1, 3), 5482],
#  ['59 ST COLUMBUS', '1ABCD', datetime.date(2016, 1, 4), 10333],
#  ['59 ST COLUMBUS', '1ABCD', datetime.date(2016, 1, 5), 12083],
#  ['59 ST COLUMBUS', '1ABCD', datetime.date(2016, 1, 6), 12385],
#  ['59 ST COLUMBUS', '1ABCD', datetime.date(2016, 1, 7), 12386],
#  ['59 ST COLUMBUS', '1ABCD', datetime.date(2016, 1, 8), 11606],
#  ['25 ST', 'R', datetime.date(2016, 1, 2), 2177],
#  ['25 ST', 'R', datetime.date(2016, 1, 3), 1807],
#  ['25 ST', 'R', datetime.date(2016, 1, 4), 3573],
#  ['25 ST', 'R', datetime.date(2016, 1, 5), 3525],
#  ['25 ST', 'R', datetime.date(2016, 1, 6), 3688],
#  ['25 ST', 'R', datetime.date(2016, 1, 7), 3738],
#  ['25 ST', 'R', datetime.date(2016, 1, 8), 3847],
#  ['UTICA AV', 'AC', datetime.date(2016, 1, 2), 9888],
#  ['UTICA AV', 'AC', datetime.date(2016, 1, 3), 8360],
#  ['UTICA AV', 'AC', datetime.date(2016, 1, 4), 15238],
#  ['UTICA AV', 'AC', datetime.date(2016, 1, 5), 15124],
#  ['UTICA AV', 'AC', datetime.date(2016, 1, 6), 15916],
#  ['UTICA AV', 'AC', datetime.date(2016, 1, 7), 15987],
#  ['UTICA AV', 'AC', datetime.date(2016, 1, 8), 15219],
#  ['V.CORTLANDT PK', '1', datetime.date(2016, 1, 2), 3787],
#  ['V.CORTLANDT PK', '1', datetime.date(2016, 1, 3), 2847],
#  ['V.CORTLANDT PK', '1', datetime.date(2016, 1, 4), 6651],
#  ['V.CORTLANDT PK', '1', datetime.date(2016, 1, 5), 6485],
#  ['V.CORTLANDT PK', '1', datetime.date(2016, 1, 6), 6866],
#  ['V.CORTLANDT PK', '1', datetime.date(2016, 1, 7), 6853],
#  ['V.CORTLANDT PK', '1', datetime.date(2016, 1, 8), 6820],
#  ['MORGAN AV', 'L', datetime.date(2016, 1, 2), 5840],
#  ['MORGAN AV', 'L', datetime.date(2016, 1, 3), 4531],
#  ['MORGAN AV', 'L', datetime.date(2016, 1, 4), 6681],
#  ['MORGAN AV', 'L', datetime.date(2016, 1, 5), 6829],
#  ['MORGAN AV', 'L', datetime.date(2016, 1, 6), 7270],
#  ['MORGAN AV', 'L', datetime.date(2016, 1, 7), 7301],
#  ['MORGAN AV', 'L', datetime.date(2016, 1, 8), 7834],
#  ['CHURCH AV', 'FG', datetime.date(2016, 1, 2), 5818],
#  ['CHURCH AV', 'FG', datetime.date(2016, 1, 3), 5167],
#  ['CHURCH AV', 'FG', datetime.date(2016, 1, 4), 10384],
#  ['CHURCH AV', 'FG', datetime.date(2016, 1, 5), 10394],
#  ['CHURCH AV', 'FG', datetime.date(2016, 1, 6), 10651],
#  ['CHURCH AV', 'FG', datetime.date(2016, 1, 7), 10722],
#  ['CHURCH AV', 'FG', datetime.date(2016, 1, 8), 10482],
#  ['49 ST', 'NQR', datetime.date(2016, 1, 2), 21129],
#  ['49 ST', 'NQR', datetime.date(2016, 1, 3), 14955],
#  ['49 ST', 'NQR', datetime.date(2016, 1, 4), 23700],
#  ['49 ST', 'NQR', datetime.date(2016, 1, 5), 23728],
#  ['49 ST', 'NQR', datetime.date(2016, 1, 6), 26332],
#  ['49 ST', 'NQR', datetime.date(2016, 1, 7), 26152],
#  ['49 ST', 'NQR', datetime.date(2016, 1, 8), 24743],
#  ['23 ST', 'NR', datetime.date(2016, 1, 2), 13102],
#  ['23 ST', 'NR', datetime.date(2016, 1, 3), 9680],
#  ['23 ST', 'NR', datetime.date(2016, 1, 4), 23666],
#  ['23 ST', 'NR', datetime.date(2016, 1, 5), 23329],
#  ['23 ST', 'NR', datetime.date(2016, 1, 6), 24656],
#  ['23 ST', 'NR', datetime.date(2016, 1, 7), 24673],
#  ['23 ST', 'NR', datetime.date(2016, 1, 8), 22752],
#  ['YORK ST', 'F', datetime.date(2016, 1, 2), 4743],
#  ['YORK ST', 'F', datetime.date(2016, 1, 3), 3739],
#  ['YORK ST', 'F', datetime.date(2016, 1, 4), 9023],
#  ['YORK ST', 'F', datetime.date(2016, 1, 5), 8988],
#  ['YORK ST', 'F', datetime.date(2016, 1, 6), 9456],
#  ['YORK ST', 'F', datetime.date(2016, 1, 7), 9609],
#  ['YORK ST', 'F', datetime.date(2016, 1, 8), 8440],
#  ['75 ST-ELDERTS', 'JZ', datetime.date(2016, 1, 2), 2057],
#  ['75 ST-ELDERTS', 'JZ', datetime.date(2016, 1, 3), 1732],
#  ['75 ST-ELDERTS', 'JZ', datetime.date(2016, 1, 4), 3943],
#  ['75 ST-ELDERTS', 'JZ', datetime.date(2016, 1, 5), 2880],
#  ['75 ST-ELDERTS', 'JZ', datetime.date(2016, 1, 6), 4099],
#  ['75 ST-ELDERTS', 'JZ', datetime.date(2016, 1, 7), 4163],
#  ['75 ST-ELDERTS', 'JZ', datetime.date(2016, 1, 8), 3964],
#  ['46 ST BLISS ST', '7', datetime.date(2016, 1, 2), 8896],
#  ['46 ST BLISS ST', '7', datetime.date(2016, 1, 3), 7124],
#  ['46 ST BLISS ST', '7', datetime.date(2016, 1, 4), 13266],
#  ['46 ST BLISS ST', '7', datetime.date(2016, 1, 5), 13417],
#  ['46 ST BLISS ST', '7', datetime.date(2016, 1, 6), 14104],
#  ['46 ST BLISS ST', '7', datetime.date(2016, 1, 7), 14211],
#  ['46 ST BLISS ST', '7', datetime.date(2016, 1, 8), 14411],
#  ['PRINCE ST', 'NR', datetime.date(2016, 1, 2), 15200],
#  ['PRINCE ST', 'NR', datetime.date(2016, 1, 3), 11070],
#  ['PRINCE ST', 'NR', datetime.date(2016, 1, 4), 14766],
#  ['PRINCE ST', 'NR', datetime.date(2016, 1, 5), 13586],
#  ['PRINCE ST', 'NR', datetime.date(2016, 1, 6), 14601],
#  ['PRINCE ST', 'NR', datetime.date(2016, 1, 7), 14669],
#  ['PRINCE ST', 'NR', datetime.date(2016, 1, 8), 14559],
#  ['138/GRAND CONC', '45', datetime.date(2016, 1, 2), 1531],
#  ['138/GRAND CONC', '45', datetime.date(2016, 1, 3), 1082],
#  ['138/GRAND CONC', '45', datetime.date(2016, 1, 4), 3257],
#  ['138/GRAND CONC', '45', datetime.date(2016, 1, 5), 3499],
#  ['138/GRAND CONC', '45', datetime.date(2016, 1, 6), 3401],
#  ['138/GRAND CONC', '45', datetime.date(2016, 1, 7), 3518],
#  ['138/GRAND CONC', '45', datetime.date(2016, 1, 8), 3582],
#  ['104 ST', 'A', datetime.date(2016, 1, 2), 0],
#  ['104 ST', 'A', datetime.date(2016, 1, 3), 0],
#  ['104 ST', 'A', datetime.date(2016, 1, 4), 2377],
#  ['104 ST', 'A', datetime.date(2016, 1, 5), 2426],
#  ['104 ST', 'A', datetime.date(2016, 1, 6), 2444],
#  ['104 ST', 'A', datetime.date(2016, 1, 7), 2519],
#  ['104 ST', 'A', datetime.date(2016, 1, 8), 2775],
#  ['SARATOGA AV', '3', datetime.date(2016, 1, 2), 4611],
#  ['SARATOGA AV', '3', datetime.date(2016, 1, 3), 3692],
#  ['SARATOGA AV', '3', datetime.date(2016, 1, 4), 8892],
#  ['SARATOGA AV', '3', datetime.date(2016, 1, 5), 8523],
#  ['SARATOGA AV', '3', datetime.date(2016, 1, 6), 9195],
#  ['SARATOGA AV', '3', datetime.date(2016, 1, 7), 9326],
#  ['SARATOGA AV', '3', datetime.date(2016, 1, 8), 9294],
#  ['SENECA AVE', 'M', datetime.date(2016, 1, 2), 1271],
#  ['SENECA AVE', 'M', datetime.date(2016, 1, 3), 1124],
#  ['SENECA AVE', 'M', datetime.date(2016, 1, 4), 2658],
#  ['SENECA AVE', 'M', datetime.date(2016, 1, 5), 2707],
#  ['SENECA AVE', 'M', datetime.date(2016, 1, 6), 2785],
#  ['SENECA AVE', 'M', datetime.date(2016, 1, 7), 2803],
#  ['SENECA AVE', 'M', datetime.date(2016, 1, 8), 2758],
#  ['40 ST LOWERY ST', '7', datetime.date(2016, 1, 2), 5898],
#  ['40 ST LOWERY ST', '7', datetime.date(2016, 1, 3), 4550],
#  ['40 ST LOWERY ST', '7', datetime.date(2016, 1, 4), 10321],
#  ['40 ST LOWERY ST', '7', datetime.date(2016, 1, 5), 10711],
#  ['40 ST LOWERY ST', '7', datetime.date(2016, 1, 6), 10930],
#  ['40 ST LOWERY ST', '7', datetime.date(2016, 1, 7), 11408],
#  ['40 ST LOWERY ST', '7', datetime.date(2016, 1, 8), 11193],
#  ['LORIMER ST', 'LG', datetime.date(2016, 1, 2), 4097],
#  ['LORIMER ST', 'LG', datetime.date(2016, 1, 3), 3514],
#  ['LORIMER ST', 'LG', datetime.date(2016, 1, 4), 5677],
#  ['LORIMER ST', 'LG', datetime.date(2016, 1, 5), 5874],
#  ['LORIMER ST', 'LG', datetime.date(2016, 1, 6), 6104],
#  ['LORIMER ST', 'LG', datetime.date(2016, 1, 7), 6325],
#  ['LORIMER ST', 'LG', datetime.date(2016, 1, 8), 5652],
#  ['PARKSIDE AV', 'BQ', datetime.date(2016, 1, 2), 3998],
#  ['PARKSIDE AV', 'BQ', datetime.date(2016, 1, 3), 3332],
#  ['PARKSIDE AV', 'BQ', datetime.date(2016, 1, 4), 5301],
#  ['PARKSIDE AV', 'BQ', datetime.date(2016, 1, 5), 5247],
#  ['PARKSIDE AV', 'BQ', datetime.date(2016, 1, 6), 5384],
#  ['PARKSIDE AV', 'BQ', datetime.date(2016, 1, 7), 5295],
#  ['PARKSIDE AV', 'BQ', datetime.date(2016, 1, 8), 5237],
#  ['CLASSON AV', 'G', datetime.date(2016, 1, 2), 2986],
#  ['CLASSON AV', 'G', datetime.date(2016, 1, 3), 2494],
#  ['CLASSON AV', 'G', datetime.date(2016, 1, 4), 4695],
#  ['CLASSON AV', 'G', datetime.date(2016, 1, 5), 4883],
#  ['CLASSON AV', 'G', datetime.date(2016, 1, 6), 5049],
#  ['CLASSON AV', 'G', datetime.date(2016, 1, 7), 5084],
#  ['CLASSON AV', 'G', datetime.date(2016, 1, 8), 5146],
#  ['28 ST', '1', datetime.date(2016, 1, 2), 5942],
#  ['28 ST', '1', datetime.date(2016, 1, 3), 4989],
#  ['28 ST', '1', datetime.date(2016, 1, 4), 15510],
#  ['28 ST', '1', datetime.date(2016, 1, 5), 14596],
#  ['28 ST', '1', datetime.date(2016, 1, 6), 14355],
#  ['28 ST', '1', datetime.date(2016, 1, 7), 14609],
#  ['28 ST', '1', datetime.date(2016, 1, 8), 12571],
#  ['8 AV', 'ACEL', datetime.date(2016, 1, 2), 19747],
#  ['8 AV', 'ACEL', datetime.date(2016, 1, 3), 16459],
#  ['8 AV', 'ACEL', datetime.date(2016, 1, 4), 21310],
#  ['8 AV', 'ACEL', datetime.date(2016, 1, 5), 20829],
#  ['8 AV', 'ACEL', datetime.date(2016, 1, 6), 23079],
#  ['8 AV', 'ACEL', datetime.date(2016, 1, 7), 24204],
#  ['8 AV', 'ACEL', datetime.date(2016, 1, 8), 20190],
#  ['KINGSTON-THROOP', 'C', datetime.date(2016, 1, 2), 4042],
#  ['KINGSTON-THROOP', 'C', datetime.date(2016, 1, 3), 3343],
#  ['KINGSTON-THROOP', 'C', datetime.date(2016, 1, 4), 6237],
#  ['KINGSTON-THROOP', 'C', datetime.date(2016, 1, 5), 6170],
#  ['KINGSTON-THROOP', 'C', datetime.date(2016, 1, 6), 6406],
#  ['KINGSTON-THROOP', 'C', datetime.date(2016, 1, 7), 6382],
#  ['KINGSTON-THROOP', 'C', datetime.date(2016, 1, 8), 6369],
#  ['GRAND ARMY PLAZ', '23', datetime.date(2016, 1, 2), 4248],
#  ['GRAND ARMY PLAZ', '23', datetime.date(2016, 1, 3), 3082],
#  ['GRAND ARMY PLAZ', '23', datetime.date(2016, 1, 4), 7685],
#  ['GRAND ARMY PLAZ', '23', datetime.date(2016, 1, 5), 7686],
#  ['GRAND ARMY PLAZ', '23', datetime.date(2016, 1, 6), 7985],
#  ['GRAND ARMY PLAZ', '23', datetime.date(2016, 1, 7), 8171],
#  ['GRAND ARMY PLAZ', '23', datetime.date(2016, 1, 8), 7331],
#  ['EASTCHSTER/DYRE', '5', datetime.date(2016, 1, 2), 1718],
#  ['EASTCHSTER/DYRE', '5', datetime.date(2016, 1, 3), 1269],
#  ['EASTCHSTER/DYRE', '5', datetime.date(2016, 1, 4), 4856],
#  ['EASTCHSTER/DYRE', '5', datetime.date(2016, 1, 5), 4747],
#  ['EASTCHSTER/DYRE', '5', datetime.date(2016, 1, 6), 5054],
#  ['EASTCHSTER/DYRE', '5', datetime.date(2016, 1, 7), 5159],
#  ['EASTCHSTER/DYRE', '5', datetime.date(2016, 1, 8), 4823],
#  ['51 ST', '6', datetime.date(2016, 1, 2), 6462],
#  ['51 ST', '6', datetime.date(2016, 1, 3), 4641],
#  ['51 ST', '6', datetime.date(2016, 1, 4), 22198],
#  ['51 ST', '6', datetime.date(2016, 1, 5), 22885],
#  ['51 ST', '6', datetime.date(2016, 1, 6), 23278],
#  ['51 ST', '6', datetime.date(2016, 1, 7), 22880],
#  ['51 ST', '6', datetime.date(2016, 1, 8), 21437],
#  ['219 ST', '25', datetime.date(2016, 1, 2), 2094],
#  ['219 ST', '25', datetime.date(2016, 1, 3), 1631],
#  ['219 ST', '25', datetime.date(2016, 1, 4), 3468],
#  ['219 ST', '25', datetime.date(2016, 1, 5), 3414],
#  ['219 ST', '25', datetime.date(2016, 1, 6), 3661],
#  ['219 ST', '25', datetime.date(2016, 1, 7), 3653],
#  ['219 ST', '25', datetime.date(2016, 1, 8), 3597],
#  ['59 ST', '456NQR', datetime.date(2016, 1, 2), 32709],
#  ['59 ST', '456NQR', datetime.date(2016, 1, 3), 23199],
#  ['59 ST', '456NQR', datetime.date(2016, 1, 4), 46204],
#  ['59 ST', '456NQR', datetime.date(2016, 1, 5), 49358],
#  ['59 ST', '456NQR', datetime.date(2016, 1, 6), 49310],
#  ['59 ST', '456NQR', datetime.date(2016, 1, 7), 49833],
#  ['59 ST', '456NQR', datetime.date(2016, 1, 8), 49926],
#  ['121 ST', 'JZ', datetime.date(2016, 1, 2), 1484],
#  ['121 ST', 'JZ', datetime.date(2016, 1, 3), 1292],
#  ['121 ST', 'JZ', datetime.date(2016, 1, 4), 2425],
#  ['121 ST', 'JZ', datetime.date(2016, 1, 5), 1978],
#  ['121 ST', 'JZ', datetime.date(2016, 1, 6), 2455],
#  ['121 ST', 'JZ', datetime.date(2016, 1, 7), 2497],
#  ['121 ST', 'JZ', datetime.date(2016, 1, 8), 2404],
#  ['MORRIS PARK', '5', datetime.date(2016, 1, 2), 774],
#  ['MORRIS PARK', '5', datetime.date(2016, 1, 3), 569],
#  ['MORRIS PARK', '5', datetime.date(2016, 1, 4), 2457],
#  ['MORRIS PARK', '5', datetime.date(2016, 1, 5), 2387],
#  ['MORRIS PARK', '5', datetime.date(2016, 1, 6), 2576],
#  ['MORRIS PARK', '5', datetime.date(2016, 1, 7), 2523],
#  ['MORRIS PARK', '5', datetime.date(2016, 1, 8), 2443],
#  ['BROAD ST', 'JZ', datetime.date(2016, 1, 2), 2063],
#  ['BROAD ST', 'JZ', datetime.date(2016, 1, 3), 1382],
#  ['BROAD ST', 'JZ', datetime.date(2016, 1, 4), 7382],
#  ['BROAD ST', 'JZ', datetime.date(2016, 1, 5), 7370],
#  ['BROAD ST', 'JZ', datetime.date(2016, 1, 6), 7696],
#  ['BROAD ST', 'JZ', datetime.date(2016, 1, 7), 7702],
#  ['BROAD ST', 'JZ', datetime.date(2016, 1, 8), 6753],
#  ['FRANKLIN ST', '1', datetime.date(2016, 1, 2), 2230],
#  ['FRANKLIN ST', '1', datetime.date(2016, 1, 3), 2015],
#  ['FRANKLIN ST', '1', datetime.date(2016, 1, 4), 5293],
#  ['FRANKLIN ST', '1', datetime.date(2016, 1, 5), 5637],
#  ['FRANKLIN ST', '1', datetime.date(2016, 1, 6), 5677],
#  ['FRANKLIN ST', '1', datetime.date(2016, 1, 7), 5877],
#  ['FRANKLIN ST', '1', datetime.date(2016, 1, 8), 5020],
#  ['NEW LOTS', 'L', datetime.date(2016, 1, 2), 2630],
#  ['NEW LOTS', 'L', datetime.date(2016, 1, 3), 2116],
#  ['NEW LOTS', 'L', datetime.date(2016, 1, 4), 5286],
#  ['NEW LOTS', 'L', datetime.date(2016, 1, 5), 5062],
#  ['NEW LOTS', 'L', datetime.date(2016, 1, 6), 5398],
#  ['NEW LOTS', 'L', datetime.date(2016, 1, 7), 5531],
#  ['NEW LOTS', 'L', datetime.date(2016, 1, 8), 5161],
#  ['JAY ST-METROTEC', 'ACF', datetime.date(2016, 1, 2), 14365],
#  ['JAY ST-METROTEC', 'ACF', datetime.date(2016, 1, 3), 11526],
#  ['JAY ST-METROTEC', 'ACF', datetime.date(2016, 1, 4), 35815],
#  ['JAY ST-METROTEC', 'ACF', datetime.date(2016, 1, 5), 35799],
#  ['JAY ST-METROTEC', 'ACF', datetime.date(2016, 1, 6), 37737],
#  ['JAY ST-METROTEC', 'ACF', datetime.date(2016, 1, 7), 38127],
#  ['JAY ST-METROTEC', 'ACF', datetime.date(2016, 1, 8), 36582],
#  ['CENTRAL AV', 'M', datetime.date(2016, 1, 2), 1738],
#  ['CENTRAL AV', 'M', datetime.date(2016, 1, 3), 1419],
#  ['CENTRAL AV', 'M', datetime.date(2016, 1, 4), 3579],
#  ['CENTRAL AV', 'M', datetime.date(2016, 1, 5), 3606],
#  ['CENTRAL AV', 'M', datetime.date(2016, 1, 6), 3705],
#  ['CENTRAL AV', 'M', datetime.date(2016, 1, 7), 3816],
#  ['CENTRAL AV', 'M', datetime.date(2016, 1, 8), 3679],
#  ['AVENUE N', 'F', datetime.date(2016, 1, 2), 1556],
#  ['AVENUE N', 'F', datetime.date(2016, 1, 3), 1442],
#  ['AVENUE N', 'F', datetime.date(2016, 1, 4), 3553],
#  ['AVENUE N', 'F', datetime.date(2016, 1, 5), 3472],
#  ['AVENUE N', 'F', datetime.date(2016, 1, 6), 3659],
#  ['AVENUE N', 'F', datetime.date(2016, 1, 7), 3649],
#  ['AVENUE N', 'F', datetime.date(2016, 1, 8), 3468],
#  ['125 ST', 'ACBD', datetime.date(2016, 1, 2), 18547],
#  ['125 ST', 'ACBD', datetime.date(2016, 1, 3), 15826],
#  ['125 ST', 'ACBD', datetime.date(2016, 1, 4), 26268],
#  ['125 ST', 'ACBD', datetime.date(2016, 1, 5), 26731],
#  ['125 ST', 'ACBD', datetime.date(2016, 1, 6), 28281],
#  ['125 ST', 'ACBD', datetime.date(2016, 1, 7), 28680],
#  ['125 ST', 'ACBD', datetime.date(2016, 1, 8), 29025],
#  ['GUN HILL RD', '5', datetime.date(2016, 1, 2), 2336],
#  ['GUN HILL RD', '5', datetime.date(2016, 1, 3), 1751],
#  ['GUN HILL RD', '5', datetime.date(2016, 1, 4), 5805],
#  ['GUN HILL RD', '5', datetime.date(2016, 1, 5), 5730],
#  ['GUN HILL RD', '5', datetime.date(2016, 1, 6), 6095],
#  ['GUN HILL RD', '5', datetime.date(2016, 1, 7), 6236],
#  ['GUN HILL RD', '5', datetime.date(2016, 1, 8), 6140],
#  ['ALLERTON AV', '25', datetime.date(2016, 1, 2), 3366],
#  ['ALLERTON AV', '25', datetime.date(2016, 1, 3), 2596],
#  ['ALLERTON AV', '25', datetime.date(2016, 1, 4), 5694],
#  ['ALLERTON AV', '25', datetime.date(2016, 1, 5), 5502],
#  ['ALLERTON AV', '25', datetime.date(2016, 1, 6), 5806],
#  ['ALLERTON AV', '25', datetime.date(2016, 1, 7), 5758],
#  ['ALLERTON AV', '25', datetime.date(2016, 1, 8), 5578],
#  ['MYRTLE AV', 'JMZ', datetime.date(2016, 1, 2), 7146],
#  ['MYRTLE AV', 'JMZ', datetime.date(2016, 1, 3), 5964],
#  ['MYRTLE AV', 'JMZ', datetime.date(2016, 1, 4), 10867],
#  ['MYRTLE AV', 'JMZ', datetime.date(2016, 1, 5), 10947],
#  ['MYRTLE AV', 'JMZ', datetime.date(2016, 1, 6), 11786],
#  ['MYRTLE AV', 'JMZ', datetime.date(2016, 1, 7), 11579],
#  ['MYRTLE AV', 'JMZ', datetime.date(2016, 1, 8), 11074],
#  ['145 ST', '3', datetime.date(2016, 1, 2), 2071],
#  ['145 ST', '3', datetime.date(2016, 1, 3), 1629],
#  ['145 ST', '3', datetime.date(2016, 1, 4), 3723],
#  ['145 ST', '3', datetime.date(2016, 1, 5), 3733],
#  ['145 ST', '3', datetime.date(2016, 1, 6), 3776],
#  ['145 ST', '3', datetime.date(2016, 1, 7), 3894],
#  ['145 ST', '3', datetime.date(2016, 1, 8), 4058],
#  ['BURKE AV', '25', datetime.date(2016, 1, 2), 1973],
#  ['BURKE AV', '25', datetime.date(2016, 1, 3), 1649],
#  ['BURKE AV', '25', datetime.date(2016, 1, 4), 3567],
#  ['BURKE AV', '25', datetime.date(2016, 1, 5), 3491],
#  ['BURKE AV', '25', datetime.date(2016, 1, 6), 3744],
#  ['BURKE AV', '25', datetime.date(2016, 1, 7), 3650],
#  ['BURKE AV', '25', datetime.date(2016, 1, 8), 3518],
#  ['20 AV', 'N', datetime.date(2016, 1, 2), 964],
#  ['20 AV', 'N', datetime.date(2016, 1, 3), 781],
#  ['20 AV', 'N', datetime.date(2016, 1, 4), 4139],
#  ['20 AV', 'N', datetime.date(2016, 1, 5), 4127],
#  ['20 AV', 'N', datetime.date(2016, 1, 6), 4446],
#  ['20 AV', 'N', datetime.date(2016, 1, 7), 4349],
#  ['20 AV', 'N', datetime.date(2016, 1, 8), 4176],
#  ['ROCKAWAY PARK B', 'AS', datetime.date(2016, 1, 2), 325],
#  ['ROCKAWAY PARK B', 'AS', datetime.date(2016, 1, 3), 226],
#  ['ROCKAWAY PARK B', 'AS', datetime.date(2016, 1, 4), 641],
#  ['ROCKAWAY PARK B', 'AS', datetime.date(2016, 1, 5), 608],
#  ['ROCKAWAY PARK B', 'AS', datetime.date(2016, 1, 6), 656],
#  ['ROCKAWAY PARK B', 'AS', datetime.date(2016, 1, 7), 672],
#  ['ROCKAWAY PARK B', 'AS', datetime.date(2016, 1, 8), 630],
#  ['BRIGHTON BEACH', 'BQ', datetime.date(2016, 1, 2), 5606],
#  ['BRIGHTON BEACH', 'BQ', datetime.date(2016, 1, 3), 4994],
#  ['BRIGHTON BEACH', 'BQ', datetime.date(2016, 1, 4), 12439],
#  ['BRIGHTON BEACH', 'BQ', datetime.date(2016, 1, 5), 12413],
#  ['BRIGHTON BEACH', 'BQ', datetime.date(2016, 1, 6), 13053],
#  ['BRIGHTON BEACH', 'BQ', datetime.date(2016, 1, 7), 12845],
#  ['BRIGHTON BEACH', 'BQ', datetime.date(2016, 1, 8), 11144],
#  ['ST LAWRENCE AV', '6', datetime.date(2016, 1, 2), 2450],
#  ...]

# %%
import numpy as np
import pandas as pd

# %%
dailystationdata2 = pd.DataFrame(dailystationdata, columns=['STATION','LINENAME','DATE','ENTRIES'])

# %%
dailystationdata2.to_csv('dailystationdata.csv')
